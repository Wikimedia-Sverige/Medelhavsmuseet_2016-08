# %%
# !pip install regex # A sligthly better version of RE
# !pip install html5lib # For Pandas read_html used to parse mapping wikitables 
# !pip install pandas # A great library for data wrangling (and analysis)

# %%
import pandas as pd 
import numpy as np
import regex
import os

# %% [markdown]
# # Metadata and mappings
# The template mapping can be found here:
#
# Phabricator task [T143212](https://phabricator.wikimedia.org/T143212)
#
# The original metadata is a Google Spreadsheet located here:
#
# https://docs.google.com/spreadsheets/d/1F43jhv_ekLfnjnvRxZjl5VmibFbRUQ2affrIkSck4WU/edit?usp=sharing
#
# The doc below is downloaded locally 2016-08-17 17:00

# %%
def strip(text):
    try:
        return text.strip()
    except AttributeError:
        return text
    
it_converters = {"Folder":strip,"Filename":strip,"Nome foto":strip,"Anno":strip,"Luogo":strip,"Nome monumento":strip,"Descrizione":strip,"Nome autore":strip}
metadata_it = pd.read_excel("./data/COH DechArch Metadata.xlsx",sheetname="Italian", converters=it_converters) # empty first row
metadata_it.columns = ["Folder","Filename","Nome foto","Anno","Luogo","Nome monumento","Descrizione","Nome autore"]

en_converters = {"Place":strip,"Monument name":strip,"Description":strip} # Skip column "Filename" we don't parse
metadata_en = pd.read_excel("./data/COH DechArch Metadata.xlsx",sheetname="English",\
                             converters=en_converters, parse_cols=[1,2,3,4],) # Skip column "Filename" --> 0

# %%
metadata_it.tail(2)
# Out:
#                                       Folder  \
# 533  3_SIRIA - Zenobia e Dura Europos e Mari
# 534  3_SIRIA - Zenobia e Dura Europos e Mari
#
#                                               Filename Nome foto  Anno  \
# 533                  21 Zenobia. 20 marzo '93. Bis.jpg   Zenobia  1993
# 534  22 Zenobia-Halacve e zalabiye. 20 marzo '93. B...   Zenobia  1993
#
#        Luogo Nome monumento Descrizione             Nome autore
# 533  Zenobia            NaN         NaN  DecArch Marina Milella
# 534  Zenobia            NaN         NaN  DecArch Marina Milella

# %%
metadata_en.tail(10)
# Out:
#        Place Monument name Description Commons_category
# 525  Zenobia           NaN         NaN              NaN
# 526  Zenobia           NaN         NaN              NaN
# 527  Zenobia           NaN   Panorama.              NaN
# 528  Zenobia           NaN         NaN              NaN
# 529  Zenobia           NaN         NaN              NaN
# 530  Zenobia           NaN         NaN              NaN
# 531  Zenobia           NaN         NaN              NaN
# 532  Zenobia           NaN         NaN              NaN
# 533  Zenobia           NaN         NaN              NaN
# 534  Zenobia           NaN         NaN              NaN

# %%
merged = pd.concat([metadata_it,metadata_en], axis=1) 
merged.tail(2)
# Out:
#                                       Folder  \
# 533  3_SIRIA - Zenobia e Dura Europos e Mari
# 534  3_SIRIA - Zenobia e Dura Europos e Mari
#
#                                               Filename Nome foto  Anno  \
# 533                  21 Zenobia. 20 marzo '93. Bis.jpg   Zenobia  1993
# 534  22 Zenobia-Halacve e zalabiye. 20 marzo '93. B...   Zenobia  1993
#
#        Luogo Nome monumento Descrizione             Nome autore    Place  \
# 533  Zenobia            NaN         NaN  DecArch Marina Milella  Zenobia
# 534  Zenobia            NaN         NaN  DecArch Marina Milella  Zenobia
#
#     Monument name Description Commons_category
# 533           NaN         NaN              NaN
# 534           NaN         NaN              NaN

# %% [markdown]
# # Create filenames

# %%
def create_filename(row_object):
    """Takes a DataFrame row from the 'merged' dataframe and returns a string filename."""
    # remove all underscores
    no_underscores = regex.sub(r"_", " ", row["Filename"])
    
    # <Filename0>, dummy, <Filename1> = <Filename>.partition(" ") 
    filename0, dummy, filename1 = no_underscores.partition(" ")
    
    # Grab the extension for later use
    ext = regex.findall(r"\.\w+",filename1)[-1]
    #print(ext)
    
    # <Filename_1_clean> = <Filename1> with "20 marzo..." removed, any dubble spaces replaced by single ones 
    # and finally the spaces substituted by underscores (_). Also remove the file type extension.
    yeardate_patt = regex.compile(r" \d+[o']? m? ?arz[o0p] ?'?\d+[\. ]?",flags=regex.I)
    year_patt = regex.compile(r" '\d\d[\.,]? ",flags=regex.I)
    
    yeardate_match = yeardate_patt.search(filename1)
    year_match = year_patt.search(filename1)
        
    if yeardate_match:
        filename_1_clean = regex.sub(yeardate_patt, " ",filename1)
        
    elif year_match and not yeardate_match:
        filename_1_clean = regex.sub(year_patt, " ",filename1)
    
    else:
        filename_1_clean = row["Filename"]
    
    # Remove the extension from filename_1_clean
    ext_patt = regex.compile(ext, flags=regex.I)
    filename_1_clean = regex.sub(ext_patt, "", filename_1_clean)
    #print(filename_1_clean)
    
    # Remove all 'Bis' from end of filename_1_clean
    filename_1_clean = regex.sub(r"Bis", "", filename_1_clean, flags=regex.I)
    #print(filename_1_clean)
    
    # Remove all leading and trailing whitespace from end of filename_1_clean
    filename_1_clean = filename_1_clean.strip(" ")
    #print(filename_1_clean)
    
    # <Filename_0_clean> = <Filename0> with any trailing brackets ()) removed.
    filename_0_clean = regex.sub(r"\).?","",filename0)
    #print(filename_0_clean)
        
    # <Folder_#>, dummy, dummy = <Folder>.partition("_")
    folder_no, dummy, dummy  = row["Folder"].partition("_")
    #print(folder_no)
    
    #Filename: <Filename_1_clean>_-_DecArch_-_<Folder_no>-<Filename_0_clean>.<ext>
    #Filename example:
    #So for 49) Palmira. Via colonnata presso il teatro. 20 marzo '93. Bis.jpg end result is
    #Palmira._Via_colonnata_presso_il_teatro._-_DecArch_-1-49.jpg
    #Palmira._Via_colonnata_presso_il_teatro._-_DecArch_-1-49.jpg
    filename = filename_1_clean + "_-_DecArch_" + folder_no + "-" + filename_0_clean + ext
    
    # Ensure no multiple spaces left
    filename = regex.sub(r" +"," ", filename)
    
    # Repalce all spaces with underscores
    filename = regex.sub(r" ", "_", filename)
    
    return filename

# %% [markdown]
# # Keyword mappings
#
# Mappings of places published as wikitables can be found here:
#
# https://commons.wikimedia.org/w/index.php?title=Special%3APrefixIndex&prefix=Associazione+DecArch%2FBatch+upload%2F&namespace=4

# %% [markdown]
# ## Places (Luogo)
#
# We have two different mappings of places, one general based on the column "Place (Luogo)" in the original metadata file and one more specific which is a combination of the columns "Place (Luogo)" and "Subject (Nome_monumento)".
#
# The mapping can be found here:
#
# https://commons.wikimedia.org/wiki/Commons:Associazione_DecArch/Batch_upload/places

# %%
place_mappings_url = "https://commons.wikimedia.org/wiki/Commons:Associazione_DecArch/Batch_upload/places"
place_mappings = pd.read_html(place_mappings_url, attrs = {"class":"wikitable"}, header=0)
place_mappings_general = place_mappings[0]
# Strip away potential surrounding whitespace
place_mappings_general["Luogo"] = place_mappings_general.Luogo.str.strip() 
place_mappings_general["wikidata"] = place_mappings_general.wikidata.str.strip()
place_mappings_general["category"] = place_mappings_general.category.str.strip() 
place_mappings_general["category"] = place_mappings_general.category.str.replace("_", " ") 

place_mappings_general = place_mappings_general.set_index("Luogo")

place_mappings_specific = place_mappings[1]
# Strip away potential surrounding whitespace
place_mappings_specific["Luogo"] = place_mappings_specific.Luogo.str.strip()
place_mappings_specific["Nome_monumento"] = place_mappings_specific.Nome_monumento.str.strip()

place_mappings_specific["category"] = place_mappings_specific.category.str.strip()
place_mappings_specific["category"] = place_mappings_specific.category.str.replace("_", " ")
place_mappings_specific["wikidata"] = place_mappings_specific.wikidata.str.strip()


place_mappings_specific["Specific_place"] = place_mappings_specific.Luogo + " " + place_mappings_specific.Nome_monumento
place_mappings_specific = place_mappings_specific[["Specific_place" ,"Luogo","Nome_monumento","category","wikidata"]]
place_mappings_specific = place_mappings_specific.set_index("Specific_place")

# %%
place_mappings_general.head(3)
# Out:
#          frequency           category  wikidata
# Luogo
# Palmira        243   Category:Palmyra   d:Q5747
# Damasco         79  Category:Damascus   d:Q3766
# Aleppo          55    Category:Aleppo  d:Q41183

# %%
place_mappings_specific.head(3)
# Out:
#                                Luogo        Nome_monumento  \
# Specific_place
# Damasco Museo                Damasco                 Museo
# Aleppo Santuario S. Simeone   Aleppo  Santuario S. Simeone
# Damasco Grande Moschea       Damasco        Grande Moschea
#
#                                                              category  \
# Specific_place
# Damasco Museo                    Category:National Museum of Damascus
# Aleppo Santuario S. Simeone  Category:Church of Saint Simeon Stylites
# Damasco Grande Moschea                        Category:Umayyad Mosque
#
#                                wikidata
# Specific_place
# Damasco Museo                 d:Q617254
# Aleppo Santuario S. Simeone  d:Q1112125
# Damasco Grande Moschea        d:Q183562

# %% [markdown]
# # Population of the Photograph template
#
# ## Template mapping

# %% [markdown]
#  The master template mapping lives as [task T143212 on Phabricator](https://phabricator.wikimedia.org/T143212)

# %% [markdown]
# ## Create wikitext for image pages
# Available as .py script on [my github](https://github.com/mattiasostmar/GAR_Syria_2016-06/blob/master/create_metatdata_textfiles.py)

# %%
# remove possible diuplicate files with other extension names
# !rm -rf ./photograph_template_texts/*

total_images = 0
OK_images = 0
uncategorized_images = 0
faulty_images = 0

filenames_file = open("./filenames_mapping.csv","w")
filenames_file.write("Folder|Original|Commons\n")

for row_no, row in merged.iterrows():
    
    # Filename: <Filename_1_clean>_-_DecArch_-_<Folder_#>-<Filename_0_clean>.<ext>
    filename = create_filename(row)

    #print("filename: {}".format(filename))
    filenames_file.write("{}|{}|{}\n".format(row["Folder"],row["Nome foto"],filename))
    
    outpath = "./photograph_template_texts/"
    nome_foto = row["Nome foto"].replace(" ", "_")
    nome_foto_0, dummy, nome_foto_1 = nome_foto.rpartition("_")
    #print("nome_foto_0: {}\ndummy: {}\nnome_foto_1: {}".format(nome_foto_0,dummy,nome_foto_1))
    
    total_images += 1
    
    template_parts = []
    
    header = "{{Photograph"
    template_parts.append(header)
    
    if not pd.isnull(row["Nome autore"]): 
        photographer = "|photographer = " + row["Nome autore"][8:]
    else:
        print("Warning! Empty Author column in row no {} photo {}".format(row_no, row["Nome foto"]))
        photographer = "|photographer = "
        faulty_images += 1
    template_parts.append(photographer)
    
    title_it = "{{it|'''" + regex.sub("_"," ",nome_foto) + "'''}}"
    #title_en = "{{en|" + regex.sub("_"," ",row["Title"][:-3]) + "}}"
    
    title = "|title = " + title_it #+ "\n" + title_en
    template_parts.append(title)
    
    if pd.notnull(row["Descrizione"]) and len(row["Descrizione"].split()) >3:
        description_it = "{{it|" + row["Descrizione"] + "}}"
    else:
        if pd.notnull(row["Nome monumento"]) and pd.notnull(row["Luogo"]) and row["Nome monumento"] != row["Luogo"]: 
            description_it = "{{it|" + str(row["Nome monumento"]) + ", " + str(row["Luogo"]) + ", " + str(row["Anno"]) + "}}"
        else:
            pass # Fill in correct code here!
            description_it = "{{it|" + str(str(row["Luogo"])) + ", " + str(row["Anno"]) + "}}"
        
    if pd.notnull(row["Description"]) and not (row["Description"] == row["Descrizione"]):
        description_en = "{{en|" + row["Description"] + "}}" # <Description> is empty though, not translated
        description = "|description = " + description_it + "\n" + description_en
    else:
        #description_en = "{{en|" + str(row["Description"]) + ", " + str(row["Place"]) + " in " + str(row["Anno"]) + "}}"
        description = "|description = " + description_it
    
    
    template_parts.append(description)
    
    depicted_people = "|depicted people ="
    template_parts.append(depicted_people)
    # Workoaround that we don't have actual specific places in mapping table
    if not row["Luogo"] == row["Nome monumento"] and pd.notnull(row["Luogo"]) and pd.notnull(row["Nome monumento"]):
        
        spec_place = row["Luogo"] + " " + row["Nome monumento"]
    
        if not place_mappings_specific.loc[spec_place]["wikidata"] == "-" \
        and pd.notnull(place_mappings_specific.loc[spec_place]["wikidata"]):
            depicted_place = "|depicted place = {{city|" + \
            place_mappings_specific.loc[spec_place]["wikidata"][2:] + "}}" #[2:] since "d:" begins wikidata string
            #print(depicted_place)
        elif not place_mappings_general.loc[row["Luogo"]]["wikidata"] == "-" or pd.isnull(place_mappings_general.loc[row["Luogo"]]["wikidata"]):
            depicted_place = "|depicted place = {{city|" + \
            place_mappings_general.loc[row["Luogo"]]["wikidata"][2:] + "}}" #[2:] since "d:" begins wikidata string
            #print(depicted_place)
        else:
            depicted_place = "|depicted place = " + row["Nome monumento"] + ", " + row["Luogo"]
            #print(depicted_place)
            
    else:
        depicted_place = "|depicted place = " + row["Luogo"]
    template_parts.append(depicted_place)
    
    # ex "...20 marzo '93..."
    common_date_patt = regex.compile(r" 20?[o']? m? ?arz[o0p] ?'?\d+[\. ]?",flags=regex.I) # matches one occasion of 2 marzo '93
    common_date_match = common_date_patt.search(row["Filename"])
    print("Filename: {}\nMatch: {}".format(row["Filename"], common_date_match))
    
    if pd.notnull(row["Anno"]):
        if common_date_match:
            date = "|date = 1993-03-20" # or better {{date|1993|3|20}}?
        else:
            date = "|date = " + str(row["Anno"])
    else:
        date = "|date = "
    template_parts.append(date)
        
    medium = "|medium =" 
    template_parts.append(medium)
    
    dimensions = "|dimensions ="
    template_parts.append(dimensions)
    
    institution = "|institution = {{Institution:Associazione DecArch}}"
    template_parts.append(institution)
    
    department = "|department ="
    template_parts.append(department)
    
    references = "|references ="
    template_parts.append(references)
    
    object_history = "|object history ="
    template_parts.append(object_history)
    
    exhibition_history = "|exhibition history ="
    template_parts.append(exhibition_history)
    
    credit_line = "|credit line ="
    template_parts.append(credit_line)
    
    inscriptions = "|inscriptions ="
    template_parts.append(inscriptions)
    
    notes = "|notes ="
    template_parts.append(notes)
    
    accession_number = "|accession number ="
    template_parts.append(accession_number)
    
    source = "|source = " + str(row["Folder"]) + "/" + str(row["Filename"]) + "\n{{Associazione DecArch cooperation project|COH}}"
    template_parts.append(source)
    
    if pd.notnull(row["Nome autore"]):
        permission = "|permission = {{CC-BY-SA-4.0|" + row["Nome autore"][8:] + " / GAR}}\n{{PermissionOTRS|id=2016042410005958}}"
    else:
        permission = "|permission = {{CC-BY-SA-4.0|Associazione DecArch}}\n{{PermissionOTRS|id=2016042410005869}}"
    template_parts.append(permission)
    
    other_versions = "|other_versions ="
    template_parts.append(other_versions)
    
    template_parts.append("}}")
    
    
    categories_list = []
    # [[Category:<Category from Specific Place> AND/OR <Category from Luogo (place)>]] 
    specific_place_category = None
    general_place_category = None
    maintanence_category = None
    batchupload_category = "[[Category:Images_from_DecArch_2016-08]]"
    translation_needed_category = "[[Category:Images_from_DecArch_needing_English_description]]"
    
    if place_mappings_specific.loc[spec_place]["category"] != "-" and pd.notnull(place_mappings_specific.loc[spec_place]["category"]): 
        
        specific_place_category = "[[" + place_mappings_specific.loc[spec_place]["category"] + "]]"
        #print("specific_place_category{}".format(specific_place_category)) 
     
    elif place_mappings_general.loc[row["Luogo"]]["category"] != "-" and pd.notnull(place_mappings_general.loc[row["Luogo"]]["category"]):
        general_place_category = "[[" + place_mappings_general.loc[row["Luogo"]]["category"] + "]]"
        #print("general_place_category: {}".format(general_place_category))
    
    # [[Category:Images_from_GAR_Syria_2016-06]]
    else:
        maintanence_category = "[[Category:Images_from_DecArch_without_categories]]"
        #print("maintanence_category: {}".format(maintanence_category))
    
    # manage content categories
    if specific_place_category :
        categories_list.append(specific_place_category)
        
    elif general_place_category and not specific_place_category:
        categories_list.append(general_place_category) 
    
    Commons_category = "[[Category:" + str(row["Commons_category"]) + "]]"
    if regex.search(r" \+ ",Commons_category):
        cats = regex.split(r" \+ ",Commons_category)
        print("{} is really {}".format(row.Commons_category, cats))
        
        for cat_no, cat in enumerate(cats):
            if cat_no == 0:
                Commons_category = cat + "]]" 
            else:
                Commons_category = "[[Category:" + cat
            
            if Commons_category != specific_place_category and Commons_category != general_place_category:
                categories_list.append(Commons_category)
                print("Commons_category: {}".format(Commons_category))
            else:
                pass
    else:
        pass
    
    if Commons_category != specific_place_category \
    and Commons_category != general_place_category \
    and pd.notnull(row["Commons_category"]):
            categories_list.append(Commons_category)
            #print("Commons_category: {}".format(Commons_category))
                
    if categories_list == None:
        print("categories_list is None")
        categories_list.append(maintanence_category)
        faulty_images += 1

    categories_list.append(batchupload_category)
    categories_list.append(translation_needed_category)
    
    if len(categories_list) >0:
        OK_images += 1
    #print(categories_list)
    print()
    
    if not os.path.exists(outpath):
        os.mkdir(outpath)
    outfile = open(outpath + filename + ".info", "w")
    outfile.write("\n".join(template_parts) + "\n" + "\n".join(categories_list))

filename_file.close()    
print("Stats: \nTotal images {}\nOK images {}\nUncategorized images {}\nImages missing author {}".format(total_images, OK_images - faulty_images, uncategorized_images, faulty_images ))
# Out:
# Filename: 1) Palmira. T.del bel temenos angolo sud-ovest. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(47, 61), match=" 20 marzo '93.">
#
# Filename: 2) Palmira. T.di bel porticato ovest. 2' marzo '93. Bis.jpg
# Match: <regex.Match object; span=(37, 51), match=" 2' marzo '93.">
#
# Filename: 3) Palmira. Temenos T. di bel ingresso facciata interna lato ovest. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(67, 81), match=" 20 marzo '93.">
#
# Filename: 4) Palmira. Temenos T. di bel ingresso facciata interna lato ovest. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(67, 81), match=" 20 marzo '93.">
#
# Filename: 5) Palmira. Temenos T. di bel ingresso facciata interna lato ovest. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(67, 81), match=" 20 marzo '93.">
#
# Filename: 6) Palmira. Temenos T. di bel ingresso facciata interna lato ovest. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(67, 81), match=" 20 marzo '93.">
#
# Filename: 7) Palmira. Temenos T. di bel. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(30, 44), match=" 20 marzo '93.">
#
# Filename: 8) Palmira. Temenos T. di bel. Plastico 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(39, 53), match=" 20 marzo '93.">
#
# Filename: 9) Palmira 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(10, 24), match=" 20 marzo '93.">
#
# Filename: 10) Palmira. Pianta. maggio '93. Bis.jpg
# Match: None
#
# Filename: 11) Palmira. T. di bel. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(23, 37), match=" 20 marzo '93.">
#
# Filename: 12) Palmira. Cella T di bel. 20 marzo '93 Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93 ">
#
# Filename: 13) Palmira. Cella T. di bel. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(29, 43), match=" 20 marzo '93.">
#
# Filename: 14) Palmira. Cella T. di bel. Adyton Nord. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(42, 56), match=" 20 marzo '93.">
#
# Filename: 15) Palmira. T. di bel. Portale d'ingresso . 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(44, 58), match=" 20 marzo '93.">
#
# Filename: 16) Alfa 35 Bis.jpg
# Match: None
#
# Filename: 17). Alfa 34. Palmira. T. di bel. Temenos, lato Ovest (ingresso). 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(65, 79), match=" 20 marzo '93.">
#
# Filename: 18) Palmira. Arco monumentale, facciata verso tetrapilo, fornice lat. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(69, 83), match=" 20 marzo '93.">
#
# Filename: 19) Palmira. Arco monumentale, facciata verso tetrapilo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(56, 70), match=" 20 marzo '93.">
#
# Filename: 20) Palmira. Arco monumentale, facciata verso tetrapilo, fornice entrale. 20 marzo '93. Bia.jpg
# Match: <regex.Match object; span=(73, 87), match=" 20 marzo '93.">
#
# Filename: 21) Palmira. Arco monumentale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(30, 44), match=" 20 marzo '93.">
#
# Filename: 22) Palmira. Arco monumentale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(30, 44), match=" 20 marzo '93.">
#
# Filename: 23) Palmira. Arco monumentale, facciata verso T. di Bel. 20 m arzo '93. Bis..jpg
# Match: <regex.Match object; span=(56, 71), match=" 20 m arzo '93.">
#
# Filename: 24) Palmira. Via colonnata tra T. di bel e Arco. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(48, 62), match=" 20 marzo '93.">
#
# Filename: 25) Palmira. Via colonnata tra T. di bel e Arco, part di X 2. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(61, 75), match=" 20 marzo '93.">
#
# Filename: 26) Palmira. Via colonnata tra T. di bel e Arco, X 2. 20 marzo '93. Bis..jpg
# Match: <regex.Match object; span=(53, 67), match=" 20 marzo '93.">
#
# Filename: 27) Palmira. Via colonnata tra T. di bel e Arco. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(48, 62), match=" 20 marzo '93.">
#
# Filename: 28) Palmira. Via colonnata tra T. di bel e Arco, parto di W 37. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(63, 77), match=" 20 marzo '93.">
#
# Filename: 29) Palmira. Via colonnata tra T. di bel e Arco. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(48, 62), match=" 20 marzo '93.">
#
# Filename: 30) Palmira. Via colonnata tra T. di bel e Arco. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(48, 62), match=" 20 marzo '93.">
#
# Filename: 31) Palmira. Via colonnata tra T. di bel e Arco. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(48, 62), match=" 20 marzo '93.">
#
# Filename: 32) Palmira. Ninfeo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(20, 34), match=" 20 marzo '93.">
#
# Filename:
bis.jpg
# Match: <regex.Match object; span=(36, 50), match=" 20 marzo '93.">
#
# Filename: 77 Damasco. Museo 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(17, 31), match=" 20 marzo '93.">
#
# Filename: 78 Damasco. Museo 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(17, 31), match=" 20 marzo '93.">
#
# Filename: 79 Damasco. Museo 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(17, 31), match=" 20 marzo '93.">
#
# Filename: 80 Damasco. Museo 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(17, 31), match=" 20 marzo '93.">
#
# Filename: 81 Damasco. Museo 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(17, 31), match=" 20 marzo '93.">
#
# Filename: 82 Damasco. Museo 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(17, 31), match=" 20 marzo '93.">
#
# Filename: 83 Damasco. Museo 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(17, 31), match=" 20 marzo '93.">
#
# Filename: 84 Damasco. Museo 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(17, 31), match=" 20 marzo '93.">
#
# Filename: 85 Damasco. Museo 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(17, 31), match=" 20 marzo '93.">
#
# Filename: 86 Damasco. Museo 23 marzo '93. Bis.jpg
# Match: None
#
# Filename: 87 Damasco. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 88 Damasco. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 89 Damasco. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 90 Damasco. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 91 Damasco. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 92 Damasco. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 93 Damasco. Museo. 20 arzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 31), match=" 20 arzo '93.">
#
# Filename: 94 Damasco. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 95 Damasco. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 96 Damasco. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 97 Damasco. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 98 Damasco. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 99 Damasco. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 100 Damasco. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(19, 33), match=" 20 marzo '93.">
#
# Filename: 101 Apamea. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 102 Apamea. 20 marzo '93. Bis...jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 103 Apamea. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 104 Apamea. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 105 Apamea. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 106 Apamea 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(10, 24), match=" 20 marzo '93.">
#
# Filename: 107 Apamea. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 108 Apamea. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 109 Apamea 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(10, 24), match=" 20 marzo '93.">
#
# Filename: 110 Apamea. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 111 Apamea. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 112 Apamea. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 113 Apamea. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 114 Apamea. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 115 Apamea. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 116 Apamea. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 117 Apamea. 20 marzo '93. Bis.jpg
# ...
#
# Filename: 173 Apamea. Antiquarium. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(24, 38), match=" 20 marzo '93.">
#
# Filename: 174 San Simeone. Nartece. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(25, 39), match=" 20 marzo '93.">
#
# Filename: 175 Apamea. Antiquarium 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(23, 37), match=" 20 marzo '93.">
#
# Filename: 176 San Simeone. Nartece sopra il portale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(42, 56), match=" 20 marzo '93.">
#
# Filename: 177 Apamea. Antiquarium. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(24, 38), match=" 20 marzo '93.">
#
# Filename: 178 San Simeone. nartece finestra laterale. 20 marzo '93.JPG
# Match: <regex.Match object; span=(43, 57), match=" 20 marzo '93.">
#
# Filename: 179 Apamea. Antiquarium. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(24, 38), match=" 20 marzo '93.">
#
# Filename: 180 San Simeone. Ottagono centrale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(35, 49), match=" 20 marzo '93.">
#
# Filename: 181 Apamea. Antiquarium. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(24, 38), match=" 20 marzo '93.">
#
# Filename: 182 San Simeone. Ottagono centrale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(35, 49), match=" 20 marzo '93.">
#
# Filename: 183 Apamea. Antiquarium. 20 marzo '93. Bis..jpg
# Match: <regex.Match object; span=(24, 38), match=" 20 marzo '93.">
#
# Filename: 184 San Simeone. Ottagono centrale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(35, 49), match=" 20 marzo '93.">
#
# Filename: 185 Apamea. Antiquarium. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(24, 38), match=" 20 marzo '93.">
#
# Filename: 186 San Simeone. Esterno bas. dx. 6 bas. centr. 20 marzo '93. Bis..jpg
# Match: <regex.Match object; span=(47, 61), match=" 20 marzo '93.">
#
# Filename: 187 Damasco. Bab Sharki (porta). 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(32, 46), match=" 20 marzo '93.">
#
# Filename: 188 San Simeone. Esterno giunzione tra bas. dx. e bas. centr. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(61, 75), match=" 20 marzo '93.">
#
# Filename: 189 Damasco presso arco romano. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(31, 45), match=" 20 marzo '93.">
#
# Filename: 190 San Simeone. Decorazione abside esterna ottagono centrale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(62, 76), match=" 20 marzo '93.">
#
# Filename: 191 Damasco. Arco romano. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(25, 39), match=" 20 marzo '93.">
#
# Filename: 192 San Simeone. Esterno abside basilica dx. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(44, 58), match=" 20 marzo '93.">
#
# Filename: 193 Damasco. Arco romano. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(25, 39), match=" 20 marzo '93.">
#
# Filename: 194 San Simeone. 1°ordine decorazione esterna abside basilica dx. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(65, 79), match=" 20 marzo '93.">
#
# Filename: 195 Damasco. Temenos T. di Zeus (forse) V. N. 28. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(49, 63), match=" 20 marzo '93.">
#
# Filename: 196 San Simeone. Basilica dx. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(29, 43), match=" 20 marzo '93.">
#
# Filename: 197 Damasco. Temenos T. di Zeus (forse) V. N. 28. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(49, 63), match=" 20 marzo '93.">
#
# Filename: 198 San Simeone. Abside basilica destra. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(40, 54), match=" 20 marzo '93.">
#
# Filename: 199 Damasco. Temenos T. di Zeus (forse). Retro Moschea. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(55, 69), match=" 20 marzo '93.">
#
# Filename: 200 San Simeone. Abside basilica dx. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(36, 50), match=" 20 marzo '93.">
#
# Filename: 201 Sergiopolis. Martirion. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(27, 41), match=" 20 marzo '93.">
#
# Filename: 202 Sergiopolis. Martirion. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(27, 41), match=" 20 marzo '93.">
#
# Filename: 203 Sergiopolis. Martirion. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(27, 41), match=" 20 marzo '93.">
#
# Filename: 204 Sergiopolis. Martirion. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(27, 41), match=" 20 marzo '93.">
#
# Filename: 205 Sergiopolis. Martirion. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(27, 41), match=" 20 marzo '93.">
#
# Filename: 206 Sergiopolis. Martirion. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(27, 41), match=" 20 marzo '93.">
#
# Filename: 207 Sergiopolis. Martirion. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(27, 41), match=" 20 marzo '93.">
#
# Filename: 208 Sergiopolis. Martirion. Decorazioni absidi laterali (forse). 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(64, 78), match=" 20 marzo '93.">
#
# Filename: 209 Sergiopolis. Martirion. Decorazioni absidi laterali (forse). 20 arzo '93. Bis.jpg
# Match: <regex.Match object; span=(64, 77), match=" 20 arzo '93.">
#
# Filename: 210 Sergiopolis. Martirion. Decorazione absidie. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(48, 62), match=" 20 marzo '93.">
#
# Filename: 211 Sergiopolis. Porta sud. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(27, 41), match=" 20 marzo '93.">
#
# Filename: 212 Sergiopolis. Martirion. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(27, 41), match=" 20 marzo '93.">
#
# Filename: 213 Sergiopolis. Martirion. 20 marzo '93. bis.jpg
# Match: <regex.Match object; span=(27, 41), match=" 20 marzo '93.">
#
# Filename: 214 Sergiopolis. Porta nord. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 215 Sergiopolis. Basilica centrale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(35, 49), match=" 20 marzo '93.">
#
# Filename: 216 Sergiopolis. Porta nord. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 217 Sergiopolis. Porta nord. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 218 Sergiopolis. Porta nord. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 219 Sergiopolis. Porta nord. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 220 Sergiopolis. Porta nord. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 221 Sergiopolis. Porta nord. Via colonnata. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(43, 57), match=" 20 marzo '93.">
#
# Filename: 222 Rasafa Sergiopolis. Mura lato sud e angolo s-w dall'interno. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(64, 78), match=" 20 marzo '93.">
#
# Filename: 223 Sergiopolis. Mura lato ovest dal martirion. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(47, 61), match=" 20 marzo '93.">
#
# Filename: 224 Sergiopolis. Cisterna s.w. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(30, 44), match=" 20 marzo '93.">
#
# Filename: 225 Sergiopolis. Mura lato nord e martirion. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(44, 58), match=" 20 marzo '93.">
#
# Filename: 226 Sergiopolis. Mura lato nord dalla basilica centrale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(56, 70), match=" 20 marzo '93.">
#
# Filename: 227 Sergiopolis. la città da sud est. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(37, 51), match=" 20 marzo '93.">
#
# Filename: 228 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 229 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 230 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 231 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 232 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 233 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 234 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 235 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 236 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 237 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 238 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 239 Aleppo. Museo. 20 marzo '93.JPG
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 240 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 241 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 242 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 243 Aleppo. Museo.j 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(19, 33), match=" 20 marzo '93.">
#
# Filename: 244 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 245 Aleppo. Museo. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(18, 32), match=" 20 marzo '93.">
#
# Filename: 246 S. Simeone. Battistero. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(27, 41), match=" 20 marzo '93.">
#
# Filename: 247 Santuario di S. Simeone. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 248 Santuario di S. Simeone. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 249 Santuario di S. Simeone. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 250 Santuario di S. Simeone. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 251 Santuario di S. Simeone. Abside basilica dx. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(48, 62), match=" 20 marzo '93.">
#
# Filename: 252 Sergiopolis. Cattedrale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 253 Sergiopolis. Cattedrale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 254 Sergiopolis. Cattedrale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 255 Sergiopolis. Cattedrale. Navata dx. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(39, 53), match=" 20 marzo '93.">
#
# Filename: 256 Sergiopolis. cattedrale navata centrale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(44, 58), match=" 20 marzo '93.">
#
# Filename: 257 Sergiopolis. cattedrale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 258 Sergiopolis. cattedrale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 259 Sergiopolis. cattedrale. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(28, 42), match=" 20 marzo '93.">
#
# Filename: 260 Sergiopolis. Martirion dec. abside. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(39, 53), match=" 20 marzo '93.">
#
# Filename: 261 Sergiopolis. Basilica centrle. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(34, 48), match=" 20 marzo '93.">
#
# Filename: 262 Sergiopolis. Basilica centrle. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(34, 48), match=" 20 marzo '93.">
#
# Filename: 263 Sergiopolis. Basilica centrle. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(34, 48), match=" 20 marzo '93.">
#
# Filename: 264 Sergiopolis. Basilica centrle. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(34, 48), match=" 20 marzo '93.">
#
# Filename: 265 Sergiopolis. Basilica centrle. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(34, 48), match=" 20 marzo '93.">
#
# Filename: 266 Sergiopolis. Basilica centrle. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(34, 48), match=" 20 marzo '93.">
#
# Filename: 267 Sergiopolis. Martiryon. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(27, 41), match=" 20 marzo '93.">
#
# Filename: 268 Sergiopolis. Martiryon. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(27, 41), match=" 20 marzo '93.">
#
# Filename: 269 Sergiopolis. Martiryon. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(27, 41), match=" 20 marzo '93.">
#
# Filename: 1 Dura Europos. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(15, 29), match=" 20 marzo '93.">
#
# Filename: 2 Dura Europos. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(15, 29), match=" 20 marzo '93.">
#
# Filename: 3 Dura Europos. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(15, 29), match=" 20 marzo '93.">
#
# Filename: 4 Dura Europos. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(15, 29), match=" 20 marzo '93.">
#
# Filename: 5 Dura Europos. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(15, 29), match=" 20 marzo '93.">
#
# Filename: 6 Dura Europos. 20 marzo'93. Bis.jpg
# Match: <regex.Match object; span=(15, 28), match=" 20 marzo'93.">
#
# Filename: 7 Dura Europos. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(15, 29), match=" 20 marzo '93.">
#
# Filename: 8 Dura Europos 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(14, 28), match=" 20 marzo '93.">
#
# Filename: 9 Mari. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(7, 21), match=" 20 marzo '93.">
#
# Filename: 10 Mari. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(8, 22), match=" 20 marzo '93.">
#
# Filename: 11 Mari. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(8, 22), match=" 20 marzo '93.">
#
# Filename: 12 Zenobia. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 13 Zenobia. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 14 Zenobia. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 15 Zenobia. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 16 Zenobia. Pretorio. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(21, 35), match=" 20 marzo '93.">
#
# Filename: 17 Zenobia. 2' marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 2' marzo '93.">
#
# Filename: 18 Zenobia. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 19 Zenobia. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 20 Zenobia. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 21 Zenobia. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(11, 25), match=" 20 marzo '93.">
#
# Filename: 22 Zenobia-Halacve e zalabiye. 20 marzo '93. Bis.jpg
# Match: <regex.Match object; span=(30, 44), match=" 20 marzo '93.">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b176d6f8ac8e> in <module>()
#     216     outfile.write("\n".join(template_parts) + "\n" + "\n".join(categories_list))
#     217
# --> 218 filename_file.close()
#     219 print("Stats: \nTotal images {}\nOK images {}\nUncategorized images {}\nImages missing author {}".format(total_images, OK_images - faulty_images, uncategorized_images, faulty_images ))
#
# NameError: name 'filename_file' is not defined

# %%
# !ls -la ./photograph_template_texts/ | head -n10
# Out:
# total 3304
# drwxr-xr-x@ 416 mos  staff  14144 12 Jul 14:47 .
# drwxr-xr-x@  17 mos  staff    578 18 Jul 10:40 ..
# -rw-r--r--@   1 mos  staff    762 18 Jul 10:41 APAMEA Acropoli con villaggio arabo _GAR_014
# -rw-r--r--@   1 mos  staff    794 18 Jul 10:41 APAMEA Case e botteghe lungo la Via colonnata _GAR_052
# -rw-r--r--@   1 mos  staff    794 18 Jul 10:41 APAMEA Case e botteghe lungo la Via colonnata _GAR_053
# -rw-r--r--@   1 mos  staff    898 18 Jul 10:41 APAMEA Il Tetraconco _GAR_009
# -rw-r--r--@   1 mos  staff    742 18 Jul 10:41 APAMEA Ingresso di un'abitazione _GAR_013
# -rw-r--r--@   1 mos  staff    798 18 Jul 10:41 APAMEA Museo - Capitello a cestello bizantino _GAR_041
# -rw-r--r--@   1 mos  staff    706 18 Jul 10:41 APAMEA Museo - Cortile _GAR_031

# %% [markdown]
# ## Tests

# %%
depicted_place = "|depicted place = {{city|" + place_mappings_specific.loc[row["Luogo"]]["wikidata"] + "}}"

# %%
place_mappings_specific
# Out:
#                                                                      Luogo  \
# Specific place
# Aleppo Cittadella                                                   Aleppo
# Palmira Tempio di Baal                                             Palmira
# Aleppo Suq                                                          Aleppo
# Qasr al-Hayr al-Sharqi Palazzo Omayyade             Qasr al-Hayr al-Sharqi
# Yabroud Necropoli di Yabroud                                       Yabroud
# Sergiopolis Cattedrale bizantina                               Sergiopolis
# Halabiyah Fortezza                                               Halabiyah
# Apamea Tra i bambini del villaggio arabo                            Apamea
# Qalb Lauzeh Lato sinistro della basilica paleoc...  Lato sinistro della basilica paleocristiana di...
# Dura Europos Fortificazione                                                            Fortificazione
# Palmira Tomba a torre                                                                   Tomba a torre
# Mushennef Tempio romano del I secolo a.C.                             Tempio romano del I secolo a.C.
# Philippopolis Mosaico romano                                                           Mosaico romano
#
#                                                                                     category  \
# Specific place
# Aleppo Cittadella                                                    Category:Aleppo citadel
# Palmira Tempio di Baal                                    Category:Temple of Baal in Palmyra
# Aleppo Suq                                                                   Category:Aleppo
# Qasr al-Hayr al-Sharqi Palazzo Omayyade                                                  NaN
# Yabroud Necropoli di Yabroud                                                             NaN
# Sergiopolis Cattedrale bizantina                                                         NaN
# Halabiyah Fortezza                                                                       NaN
# Apamea Tra i bambini del villaggio arabo                                                 NaN
# Mari Palazzo di Zimri-Lin                                                                NaN
# Palmyra Interno dell'Ipogeo di Artaban                                                   NaN
# Hama Centro Storico di Hama - particolare                                                NaN
# Burjikeh rovine bizantine                                                                NaN
# Darkita rovine bizantine                                                                 NaN
# Hama Noria                                                                               NaN
# Palmyra Interno di una tomba a torre                                                     NaN
# Tell Barry scavi                                                                         NaN
# Tartus Resti del centro medievale                                                        NaN
# Jebl Zawiya Torre posizionata accanto a una gra...                                       NaN
# Aleppo Quartieri di Aleppo                                                               NaN
# Al Quanawat Caseggiato romano                                                            NaN
# Apamea Particolare delle sale espositive del Museo                                       NaN
# Apamea Via colonnata                                                                     NaN
# Cyrrus Teatro romano                                                                     NaN
# Palmyra Arco di Trionfo                                                                  NaN
# Aleppo Museo                                                                             NaN
# Aleppo Moschea Omayyadi                                                                  NaN
# Dura Europos Cittadella fortificazione sull'Efrate                                       NaN
# Bosra Teatro romano                                                                      NaN
# Palmira Fakhr-al-Din al-Maani                                                            NaN
# Ebla Palazzo G                                                                           NaN
# ...                                                                                      ...
# Palmira Tempio della dea Allat/Atena                                                     NaN
# Hama Particolare di una Noria                                                            NaN
# Apamea Particolare della Via colonnata                                                   NaN
# Palmira Teatro romano                               Category:Ancient Roman theater (Palmyra)
# Palmyra Necropoli delle tombe a torre                                                    NaN
# Kanatha Al Qanawat particolare finestra in piet...                                       NaN
# Palmira Via Colonnata                                                                    NaN
# Palmira rilievo funerario                                                                NaN
# Damasco Chiesa bizantina e tempio di Giove                                               NaN
# Tell Barri Tell Barri                                                                    NaN
# Apamea Via colonnata - particolare di una trabe...                                       NaN
# Latakia (Laodicea) Colonnato e travatura del Foro                                        NaN
# Ugarit Tomba nel cortile di un palazzo                                                   NaN
# Deir Mar Musa Santuario di San Mosè l'Abissino ...          Category:Church of Deir Mar Musa
# Aleppo Abside della basilica bizantina di Khara...                                       NaN
# San Simeone Basilica                                                                     NaN
# Bosra Grandi terme                                                                       NaN
# Aleppo Resti della basilica bizantina di Kharab...                                       NaN
# Hama Museo Archeologico - Sarcofago tardoantico                                          NaN
# Palmira Tempio di Baal - Architrave con scena d...        Category:Temple of Baal in Palmyra
# Ebla Palazzo meridionale                                                                 NaN
# Maalula Panorama delle grotte di Maalula verso ...                                       NaN
# Damasco Mosaico bizantino                                                                NaN
# Palmira Qualah ibn Maan_001                                                              NaN
# Aleppo Corte interna della moschea                                                       NaN
# Qalb Lauzeh Lato sinistro della basilica paleoc...                                       NaN
# Dura Europos Fortificazione                                                              NaN
# Palmira Tomba a torre                                                                    NaN
# Mushennef Tempio romano del I secolo a.C.                                                NaN
# Philippopolis Mosaico romano                                                             NaN
#
#                                                      wikidata
# Specific place
# Aleppo Cittadella                                   d:Q206231
# Palmira Tempio di Baal                              d:Q797481
# Aleppo Suq                                                NaN
# Qasr al-Hayr al-Sharqi Palazzo Omayyade                   NaN
# Yabroud Necropoli di Yabroud                              NaN
# Sergiopolis Cattedrale bizantina                          NaN
# Halabiyah Fortezza                                        NaN
# Apamea Tra i bambini del villaggio arabo                  NaN
# Mari Palazzo di Zimri-Lin                                 NaN
# Palmyra Interno dell'Ipogeo di Artaban                    NaN
# Hama Centro Storico di Hama - particolare                 NaN
# Burjikeh rovine bizantine                                 NaN
# Darkita rovine bizantine                                  NaN
# Hama Noria                                                NaN
# Palmyra Interno di una tomba a torre                      NaN
# Tell Barry scavi                                          NaN
# Tartus Resti del centro medievale                         NaN
# Jebl Zawiya Torre posizionata accanto a una gra...        NaN
# Aleppo Quartieri di Aleppo                                NaN
# Al Quanawat Caseggiato romano                             NaN
# Apamea Particolare delle sale espositive del Museo        NaN
# Apamea Via colonnata                                      NaN
# Cyrrus Teatro romano                                      NaN
# Palmyra Arco di Trionfo                                   NaN
# Aleppo Museo                                              NaN
# Aleppo Moschea Omayyadi                                   NaN
# Dura Europos Cittadella fortificazione sull'Efrate        NaN
# Bosra Teatro romano                                       NaN
# Palmira Fakhr-al-Din al-Maani                             NaN
# Ebla Palazzo G                                            NaN
# ...                                                       ...
# Palmira Tempio della dea Allat/Atena                      NaN
# Hama Particolare di una Noria                             NaN
# Apamea Particolare della Via colonnata                    NaN
# Palmira Teatro romano                                     NaN
# Palmyra Necropoli delle tombe a torre                     NaN
# Kanatha Al Qanawat particolare finestra in piet...        NaN
# Palmira Via Colonnata                                     NaN
# Palmira rilievo funerario                                 NaN
# Damasco Chiesa bizantina e tempio di Giove                NaN
# Tell Barri Tell Barri                                     NaN
# Apamea Via colonnata - particolare di una trabe...        NaN
# Latakia (Laodicea) Colonnato e travatura del Foro         NaN
# Ugarit Tomba nel cortile di un palazzo                    NaN
# Deir Mar Musa Santuario di San Mosè l'Abissino ...          -
# Aleppo Abside della basilica bizantina di Khara...        NaN
# San Simeone Basilica                                      NaN
# Bosra Grandi terme                                        NaN
# Aleppo Resti della basilica bizantina di Kharab...        NaN
# Hama Museo Archeologico - Sarcofago tardoantico           NaN
# Palmira Tempio di Baal - Architrave con scena d...  d:Q797481
# Ebla Palazzo meridionale                                  NaN
# Maalula Panorama delle grotte di Maalula verso ...        NaN
# Damasco Mosaico bizantino                                 NaN
# Palmira Qualah ibn Maan_001                               NaN
# Aleppo Corte interna della moschea                        NaN
# Qalb Lauzeh Lato sinistro della basilica paleoc...        NaN
# Dura Europos Fortificazione                               NaN
# Palmira Tomba a torre                                     NaN
# Mushennef Tempio romano del I secolo a.C.                 NaN
# Philippopolis Mosaico romano                              NaN
#
# [265 rows x 4 columns]
