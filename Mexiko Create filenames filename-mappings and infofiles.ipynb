# %%
# !pip install --process-dependency-links git+https://github.com/lokal-profil/BatchUploadTools.git@py3compat
# Out:
# Collecting git+https://github.com/lokal-profil/BatchUploadTools.git@py3compat
#   Cloning https://github.com/lokal-profil/BatchUploadTools.git (to py3compat) to /private/var/folders/dy/hz8hh_r54pj1kclmpfg_l40r0000gn/T/pip-dpl3uepq-build
#   DEPRECATION: Dependency Links processing has been deprecated and will be removed in a future release.
# Collecting pywikibot==3.0-dev (from BatchUploadTools==0.0.1)
#   Cloning https://github.com/wikimedia/pywikibot-core.git to /private/var/folders/dy/hz8hh_r54pj1kclmpfg_l40r0000gn/T/pip-build-wwnv5wa8/pywikibot
# ^COperation cancelled by user

# %%
from batchupload import helpers
import pandas as pd
from collections import Counter
import os
import regex
import pickle
#import batchupload.helpers as helpers # error when using Python 3.5.2 :: Anaconda custom (x86_64) on MacBook Air

mexiko = pickle.load(open("./mexiko_df_final.pickle","rb"))

# %%
pd.set_option('display.max_rows', 5)
pd.set_option('max_seq_items', 10)

# %% [raw]
# # Ensure this computer has got NLTK tokenizers
# nltk.download()

# %% [markdown]
# The metadata file on [Google Docs](https://docs.google.com/spreadsheets/d/1YXusiepersJ6_XGoUVEE0jfGh5NJs-5Rds2_l5ZbGik/edit?usp=sharing)
#
# The collection object "Linné-Mexiko" from Etnografiska Museet is [on Carlotta](http://collections.smvk.se/carlotta-em/web/object/1460547)
#
# A list of all the photographs is listed [on Carlotta](http://collections.smvk.se/carlotta-em/web/object/1460547/CHILDREN/9)
#
# Here is the full search in the Database from Etnografiska Museet [in K-SAMSOK](http://www.varldskulturmuseerna.se/etnografiskamuseet/forskning-samlingar/sok-i-samlingarna1/?ksamsearchtext=mexiko+sigvald+tula&radio-group=andmatch&itemtype=samling&ksamsubmit=S%C3%B6k)

# %% [markdown]
# # 0. Read in the metadata

# %%
mexiko_test = pd.read_excel("excel-export.xls", sheetname="Mexiko")
mexiko_test.columns
# Out:
# Index(['Fotonummer', 'Postnr.', 'Motivord', 'Beskrivning', 'Land, foto',
#        'Region, foto', 'Ort, foto', 'Etnisk grupp, avb.', 'Fotodatum',
#        'Personnamn / fotograf', 'Personnamn / avbildad', 'Sökord',
#        'Händelse / var närvarande vid', 'Länk'],
#       dtype='object')

# %%
def strip(text):
    try:
        return text.strip()
    except AttributeError:
        return text
    
mexiko_converters = {"Fotonummer":strip,"Postnr":strip,"Motivord":strip,"Beskrivning":strip,"Land, foto":strip,
                     "Region, foto":strip,"Ort, foto":strip,"Etnisk grupp, avb.":strip,"Fotodatum":strip,
                    "Personnamn / fotograf":strip, "Personnamn / avbildad":strip, "Sökord":strip,
                    "Händelse / var närvarande vid":strip, "Länk":strip}

mexiko = pd.read_excel("excel-export.xls", sheetname="Mexiko", converters=mexiko_converters)

# %% [markdown]
# ## Add sub-collection metadata field "description"
#
# * Add these to the final images in the infobox

# %%
sub_desc = {"a":"Teotihuacan (241) utgrävningar, fornlämningar, invånare",
"b": "Mexiko (29) utgrävningar, fornlämningar mm",
"c": "Tula (32) landskap, miljöer, invånare, fornlämningar",
"d": "Oaxaca (54) fornlämningar, invånare, miljöer mm. Nr.1 saknas",
"e": "Teopanzolco, Xochicalco (50) fornlänningar nr.51 saknas",
"f": "Yucatan, Chichen Itza fornlämningar, landskap. Två kartonger, 352 saknas",
"g": "Yucatan, Uxmal (113) fornlämningar",
"h": "Yucatan, Sayil (9) fornlämningar",
"i": "Yucatan, Kabah (59) fornlämningar",
"j": "Yucatan, Labna (90) fornlämningar, bilresa längs landsvägen",
"k": "Yucatan, Merida (42) miljöer, invånare",
"l": "Yucatan, Mona (11) invånare, miljöer",
"m": "Yucatan, Ticul (2) boskap",
"n": "Yucatan, Dzitas (5) miljöer",
"o": "Yucatan, Villa Hermosa (14) flygfoton",
"p": "Yucatan, skilda orter (25) tågresan Vera Cruz- Mexico",
"q": "Teotihuacan (156) arkeologiska föremål"}

# %%
mexiko["subcol_desc"] = 0
for index, row in mexiko.iterrows():
    #print(mexiko.loc[index,"subcol_desc"])
    for key in sub_desc:
        #print(type(row.Fotonummer))
        initial_numbers, left_dot, letter_plus_last_numbers = row.Fotonummer.partition(".")
        letter, dot, last_numbers = letter_plus_last_numbers.partition(".")
        #print(letter)
        if letter == key:
            #print("Match! index: {} letter:{} key:{} desc: {}".format(index, letter, key, sub_desc[key]))
            mexiko.loc[index, "subcol_desc"] = sub_desc[key] 
mexiko.subcol_desc.value_counts()
# Out:
# Yucatan, Chichen Itza fornlämningar, landskap. Två kartonger, 352 saknas    376
# Teotihuacan (241) utgrävningar, fornlämningar, invånare                     274
#                                                                            ...
# Yucatan, Dzitas (5) miljöer                                                   5
# Yucatan, Ticul (2) boskap                                                     2
# Name: subcol_desc, dtype: int64

# %% [markdown]
# # Add wiki-formatted URL-link
#
# * Use existing helper [template](https://commons.wikimedia.org/wiki/Template:SMVK-EM-link)
#
# ex: http://kulturarvsdata.se/SMVK-EM/fotografi/html/2786726
#
# {{SMVK-EM-link|foto|1461871|0713.0002}}
#
# - param 1: fotografi
# - param 2: 2786726
# - param 3: 0307.a.0001

# %%
for index, row in mexiko.iterrows():
    print(row["Länk"])
    break
# Out:
# http://kulturarvsdata.se/SMVK-EM/fotografi/html/2786726

# %%
first, slash, id_str = "http://kulturarvsdata.se/SMVK-EM/fotografi/html/2786726".rpartition("/")
id_str
# Out:
# '2786726'

# %%
for index, row in mexiko.iterrows():
    url = row["Länk"]
    #first, slash, id_str = url.rpartition("/")
    #new_url = "[" + url + " Fotonummer: " + id_str + "]"
    #mexiko.loc[index, "wiki_url"] = new_url
    
    left_side, slash, id_str = url.rpartition("/")
    template = "{{SMVK-EM-link|1=foto|2=" + id_str + "|3=" + row["Fotonummer"] + "}}"
    mexiko.loc[index, "SMVK-EM-link"] = template
    
mexiko
# Out:
#          Fotonummer  Postnr.                     Motivord  \
# 0       0307.a.0001  2786726             karta, Stockholm
# 1     0307.a.0002.a  2786708              pyramid, tempel
# ...             ...      ...                          ...
# 1440    0307.q.0155  2806174  figur, skulptur, Xipe Totec
# 1441    0307.q.0156  2806179  figur, skulptur, Xipe Totec
#
#                                             Beskrivning Land, foto  \
# 0     Teotihuacans monumentalbyggnader utlagda på ka...        NaN
# 1                                         Solpyramiden.     Mexiko
# ...                                                 ...        ...
# 1440             Arkeologiskt föremål från Teotihuacan.     Mexiko
# 1441             Arkeologiskt föremål från Teotihuacan.     Mexiko
#
#      Region, foto    Ort, foto Etnisk grupp, avb. Fotodatum  \
# 0             NaN          NaN                NaN       NaN
# 1             NaN  Teotihuacan                NaN      1932
# ...           ...          ...                ...       ...
# 1440          NaN          NaN                NaN      1932
# 1441          NaN          NaN                NaN      1932
#
#      Personnamn / fotograf Personnamn / avbildad                    Sökord  \
# 0                      NaN                   NaN                       NaN
# 1           Linné, Sigvald                   NaN                       NaN
# ...                    ...                   ...                       ...
# 1440        Linné, Sigvald                   NaN  arkeologi, ben, lerfigur
# 1441        Linné, Sigvald                   NaN       arkeologi, lerfigur
#
#           Händelse / var närvarande vid  \
# 0                                   NaN
# 1     Utgrävningar i Teotihuacan (1932)
# ...                                 ...
# 1440  Utgrävningar i Teotihuacan (1932)
# 1441  Utgrävningar i Teotihuacan (1932)
#
#                                                    Länk  \
# 0     http://kulturarvsdata.se/SMVK-EM/fotografi/htm...
# 1     http://kulturarvsdata.se/SMVK-EM/fotografi/htm...
# ...                                                 ...
# 1440  http://kulturarvsdata.se/SMVK-EM/fotografi/htm...
# 1441  http://kulturarvsdata.se/SMVK-EM/fotografi/htm...
#
#                                             subcol_desc  \
# 0     Teotihuacan (241) utgrävningar, fornlämningar,...
# 1     Teotihuacan (241) utgrävningar, fornlämningar,...
# ...                                                 ...
# 1440             Teotihuacan (156) arkeologiska föremål
# 1441             Teotihuacan (156) arkeologiska föremål
#
#                                            SMVK-EM-link
# 0       {{SMVK-EM-link|1=foto|2=2786726|3=0307.a.0001}}
# 1     {{SMVK-EM-link|1=foto|2=2786708|3=0307.a.0002.a}}
# ...                                                 ...
# 1440    {{SMVK-EM-link|1=foto|2=2806174|3=0307.q.0155}}
# 1441    {{SMVK-EM-link|1=foto|2=2806179|3=0307.q.0156}}
#
# [1442 rows x 16 columns]

# %% [markdown]
# Tips: Om det bara finns generiskt motivord och det finns Ort, foto OCH Motivord:
# Finns Commons-kategori som heter typ Pyramids in Techuacan?
# pröva Motivord

# %% [markdown]
# # Statistics: Not OK_to_upload

# %%
bad_keywords = ["pyramid","tempel","Ciudadela","tempelpyramid", "tempelpyramider","ruiner","fornlämningar"]
no_ort = 0
no_ort_and_generic_motivord = 0
no_ort_no_motivord = 0

for index, row in mexiko.iterrows():
    if pd.isnull(row["Beskrivning"]) and pd.isnull(row["Ort, foto"]):
        no_ort += 1
        if pd.notnull(row["Motivord"]):
            sep_motivord = [token.strip() for token in row["Motivord"].split(",")]
            diff = set(sep_motivord) - set(bad_keywords)
            if diff == set(): # Technically bad photos
                no_ort_and_generic_motivord += 1
        elif pd.isnull(row["Motivord"]):
            no_ort_no_motivord += 1
                
print("no ort: {}\nno ort plus generic motivord: {}\nno ort, no motivord: {}".format(no_ort, no_ort_and_generic_motivord, no_ort_no_motivord))
# Out:
# no ort: 93
# no ort plus generic motivord: 1
# no ort, no motivord: 73

# %% [markdown]
# # Collect keyword mappings and create dataframes
#
# Keywords for the Mexiko dataset are published as mappingtables on [Commons](https://commons.wikimedia.org/wiki/Commons:Medelhavsmuseet/batchUploads/Mexiko_keywords).

# %%
kw_maps_url = "https://commons.wikimedia.org/wiki/Commons:Medelhavsmuseet/batchUploads/Mexiko_keywords"
kw_maps_list = pd.read_html(kw_maps_url, attrs = {"class":"wikitable"}, header=0)
ort_foto = kw_maps_list[0]
motivord = kw_maps_list[1]
beskr_bi = kw_maps_list[2]
beskr_uni = kw_maps_list[3]
kw_maps = pd.concat([ort_foto,motivord,beskr_bi,beskr_uni])
#kw_maps = kw_maps.dropna()
print("tot: {} keywords".format(len(kw_maps)))
print("filled in: {}".format(len(kw_maps[:][(pd.notnull(kw_maps["wikidata"])) & (pd.notnull(kw_maps["category"]))])))
kw_maps = kw_maps[:][(pd.notnull(kw_maps["wikidata"])) & (pd.notnull(kw_maps["category"]))] # 33 at 2016-11-24
kw_maps.head()
# Out:
# tot: 202 keywords
# filled in: 113
#         keyword  frequency               category      wikidata
# 0  Chichén Itzá      376.0  Category:Chichén_Itzá  Chichen Itza
# 1   Teotihuacan      272.0   Category:Teotihuacán   Teotihuacan
# 2           n/a      234.0                      -             -
# 3         Uxmal      113.0         Category:Uxmal         Uxmal
# 4         Labna       69.0         Category:Labná         Labna

# %% [markdown]
# # Create filenames and filenames-mapping file

# %%
def create_new_filename(row, filenames_file):
    import pickle
    
    old_filename = row["Fotonummer"] + ".tif"
    
    # Remove the extension from filename_1_clean
    fname_parts = row["Fotonummer"].split(".")
    
    
    def create_id_str(fname_parts):
        id_str = None
        if len(fname_parts) == 3 and fname_parts[-1]:
            id_str = fname_parts[2]
        elif len(fname_parts) == 4 and fname_parts[-1].isalpha():
            id_str = fname_parts[2] + "." + fname_parts[3]
        else:
            print("Something wrong when creating ext and id_str!")
            print("fname_parts: {}".format(fname_parts))
            return
                  #return print("ext: {}\nid_str: {}".format(ext, id_str))
        return id_str # skip extension, assume all extensions are .tif
    
    def construct_new_name_from_dataframe(row, id_str):
        ext = ".tif"
        new_fname = ""
        if pd.notnull(row["Beskrivning"]):
            new_fname += row["Beskrivning"]
            new_fname += "_-_"
            new_fname += "SMVK-EM"
            new_fname += "_-_"
            new_fname += id_str
            
            new_fname += ext
            
        elif pd.isnull(row["Beskrivning"]) and pd.notnull(row["Händelse / var närvarande vid"]) and pd.notnull(row["Motivord"]):
            new_fname += row["Motivord"]
            new_fname += " "
            new_fname += row["Händelse / var närvarande vid"]
            new_fname += "_-_"
            new_fname += "SMVK-EM"
            new_fname += "_-_"
            new_fname += id_str
            new_fname += ext
            
        elif pd.isnull(row["Beskrivning"]) and pd.notnull(row["Händelse / var närvarande vid"]) and pd.isnull(row["Motivord"]):
            new_fname += row["Händelse / var närvarande vid"]
            new_fname += "_-_"
            new_fname += "SMVK-EM"
            new_fname += "_-_"
            new_fname += id_str
            new_fname += ext
            print("Fotonummer {}: only 'Händelse / var närvarande vid' added to new filename".format(row["Fotonummer"]))
        
        else:
            print("Fotonummer {} could not be created a new filename for".format(row["Fotonummer"]))
        #print("type(new_fname): {}".format(type(new_fname)))
        return new_fname
    
    def compose_description(row):
        description = ""
        if pd.notnull(row["Beskrivning"]):
            description += row["Beskrivning"]
        if pd.isnull(row["Beskrivning"]) and pd.notnull(row["Händelse / var närvarande vid"]):
            description += row["Händelse / var närvarande vid"]
        return description
    
    def append_new_filename_to_filenames_mapping_file(filenames_file, old_filename, new_filename):
        filenames_file.write("{}|{}\n".format(old_filename, new_filename))
        return 
    
    id_str = create_id_str(fname_parts)
    #print("id_str: {}".format(id_str))
    if id_str:
        ########## Not using BatchUploadTools ###############################
        #fname = construct_new_name_from_dataframe(row, id_str) # without using BatchUploadTools
        #append_new_filename_to_filenames_mapping_file(filenames_file, old_filename, fname)
        #print("fname: {}\nchecked_fname: {}\n".format(fname, checked_fname))
        #return fname
        
        ########## Using BatchUploadTools ####################################
        description = compose_description(row)
        checked_fname = helpers.format_filename(description, "SMVK", row["Fotonummer"]) # skip id_str, since not unique
        #print("Fotonummer: {}\nchecked_fname returns:{}".format(row["Fotonummer"],checked_fname))
        return checked_fname
       
        
    else:
        return print("Could not create a new filename for photo: {}".format(row["Fotonummer"]))

# %% [markdown]
# Infobox mapping is available on [Phabricator](https://phabricator.wikimedia.org/T144485)

# %%
def create_infofiles(row, filenames_file, not_ok_file):
    bad_keywords = ["pyramid","tempel","Ciudadela","tempelpyramid", "tempelpyramider","ruiner","fornlämningar"]
    outpath = "./infofiles/"
    infotext = "{{photograph\n"
    
    new_filename = create_new_filename(row, filenames_file)
    
    lacking_description = False
    lacking_photographer = False
    personnamn_not_even = False
    linne_category = False
    content_categories = False
    OK_to_upload = True
    no_content_categories = 0
    
    if pd.notnull(row["Personnamn / fotograf"]):
        if "Apenes" in row["Personnamn / fotograf"]:
            infotext +="|photographer       =  " + "{{creator:Sigvald_Linné}} / Ola Apenes\n"
        elif "Sigvald" in row["Personnamn / fotograf"]:
            linne_category == True
        else:
            infotext += "|photographer       =  " + row["Personnamn / fotograf"].strip() + "\n"
    if pd.isnull(row["Personnamn / fotograf"]):
        if row["Personnamn / fotograf"] == "Linné, Sigvald": # not all cases
            infotext += "|photographer       =  "+ "{{creator:Sigvald_Linné}}\n" 
        lacking_photographer = True
    
    infotext += "|title              = \n"
    
    en_description = "{{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}\n"
    if pd.notnull(row["Beskrivning"]):
        if pd.notnull(row["Ort, foto"]) and pd.notnull(row["Motivord"]) and pd.notnull(row["Händelse / var närvarande vid"]):
            infotext += "|description       = {{sv|" + row["Beskrivning"] + " " + str(row["Händelse / var närvarande vid"]) + " " + row["Ort, foto"] + " " + row["Motivord"] + "}}\n"
        elif pd.notnull(row["Ort, foto"]) and pd.isnull(row["Motivord"]):
            infotext += "|description       = {{sv|" + row["Beskrivning"] + " " + str(row["Händelse / var närvarande vid"]) + " " + row["Ort, foto"] + "}}\n"
        elif pd.isnull(row["Ort, foto"]) and pd.notnull(row["Motivord"]):
            infotext += "|description       = {{sv|" + row["Beskrivning"] + " " + str(row["Händelse / var närvarande vid"]) + " " + row["Motivord"] + "}}\n"
        elif pd.isnull(row["Ort, foto"]) and pd.isnull(row["Motivord"]):    
            infotext += "|description       = {{sv|" + row["Beskrivning"] + " " + str(row["Händelse / var närvarande vid"]) + " " + "}}\n"
        infotext += en_description
    if pd.isnull(row["Beskrivning"]):
        lacking_description = True
        if pd.isnull(row["Ort, foto"]):
            OK_to_upload = False
        elif pd.notnull(row["Ort, foto"]) and pd.notnull(row["Motivord"]) and pd.notnull(row["Händelse / var närvarande vid"]):
            infotext += "|description       = {{sv|" + row["Ort, foto"] + " " + row["Händelse / var närvarande vid"] + " " + row["Motivord"] + "}}\n"
            infotext += en_description
        
    depicted_people = ""
    if pd.notnull(row["Personnamn / avbildad"]):
        lista = row["Personnamn / avbildad"].split(", ")
        for i, j in zip(lista[::2], lista[1::2]):
            if j + " " + i == "Sigvald Linne":
                linne_category = True
                depicted_people += "[[q:Q5959424|Sigvald Linné]]\n[[Category:Sigvald_Linné]]\n"
            else:
                depicted_people += j + " " + i + "/"
    depicted_people = depicted_people.rstrip("/") 
    infotext += "|depicted people    = " + depicted_people + "\n"
        
    if pd.notnull(row["Ort, foto"]):
        infotext += "|depicted place     = " + str(row["Ort, foto"]) + "\n"
    
    if pd.notnull(row["Fotodatum"]):    
        infotext += "|date               = " + row["Fotodatum"] + "\n"

    infotext += "|medium             = \n"
    infotext += "|dimensions         = \n"    
    
    infotext += "|institution        = {{Institution:Statens museer för världskultur}}\n"
    
    infotext += "|department         = [[d:Q1371375|Etnografiska muséet]]\n"
    
    infotext += "|references         = \n"
    infotext += "|object history     = \n"
    infotext += "|exhibition history = \n"
    infotext += "|credit line        = \n"
    infotext += "|inscriptions       = \n"
    infotext += "|notes              = \n"
    infotext += "|accession number   = " + str(row["SMVK-EM-link"]) + "\n"
    
    if pd.notnull(row["Fotonummer"]):
        infotext += "|source             = Original file name, as receieved from SMVK:  <br /> '''" + str(row["Fotonummer"]) +\
        ".tif'''\n{{SMVK_cooperation_project|COH|museum=EM}}\n"
        
    infotext += "|permission         = {{cc-zero}}\n"
    infotext += "|other_versions     =\n"
    infotext += "}}"
    
    # categories
    categories = "[[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]\n[[Category:Images_from_SMVK_2016-11]]"
    content_categories_set = set()
    for index, kw in kw_maps.iterrows():
        #print(kw["keyword"])
        patt = regex.compile(r"\b" + kw["keyword"] + r"\b", regex.I)
        #print(patt)
        
        
        if pd.notnull(row["Beskrivning"]):
            if patt.search(row["Beskrivning"]):
                #print("Beskrivnig: {}\nkw found {}\n".format(row["Beskrivning"], kw["keyword"]))
                if pd.notnull(kw["category"]) and kw["category"] != "-":
                    content_categories = True
                    content_categories_set.add("[[" + kw["category"] + "]]") 
        
        if pd.notnull(row["Motivord"]):
            list_of_motivord = row["Motivord"].split(", ")
            for motivord in list_of_motivord:
                if patt.search(motivord):
                    if pd.notnull(kw["category"]) and kw["category"] != "-":
                        content_categories = True
                        content_categories_set.add("[[" + kw["category"] + "]]") 
                    
        if pd.notnull(row["Sökord"]):
            list_of_sokord = row["Sökord"].split(", ")
            for sokord in list_of_sokord:
                if patt.search(sokord):
                    if pd.notnull(kw["category"]) and kw["category"] != "-":
                        content_categories = True
                        content_categories_set.add("[[" + kw["category"] + "]]") 
                        
        if pd.notnull(row["Ort, foto"]):
            if patt.search(row["Ort, foto"]):
                if pd.notnull(kw["category"]) and kw["category"] != "-":
                    content_categories = True
                    content_categories_set.add("[[" + kw["category"] + "]]") 
    #print("content_categories_set: \n{}".format(content_categories_set))
    
    content_categories_string = ""    
    if content_categories:
        for content_category in content_categories_set:
            content_categories_string += "\n" + content_category
        categories += "\n" + content_categories_string
        
    else:
        no_content_categories += 1
        categories += "\n[[Category:Images_from_SMVK_without_content_categories]]"
        OK_to_upload = False
    
    if personnamn_not_even:
        categories += "\n[[Category:Images_from_SMVK_with_faulty_depicted_persons]]"
    if lacking_description:
        categories += "\n[[Category:Images_from_SMVK_without_full_description]]"
    if lacking_photographer:
        categories += "\n[[Category:Images_from_SMVK_without_photographer]]"
    if linne_category:
        categories += "\n[[Category:Sigvald_Linné]]"
    
    categories.lstrip()
    
    if OK_to_upload:
        #print(OK_to_upload)
        #print("new_filename: {} + .info".format(new_filename))
        outfile = open(outpath + new_filename + ".info","w")
        outfile.write(infotext + "\n" + categories)
        outfile.close()
    else:
        not_ok_row = ""
        link = "| " + str(row["SMVK-EM-link"]) + "\n"
        desc = "| " + str(row["Beskrivning"]) + "\n"
        place = "| " + str(row["Ort, foto"]) + "\n"
        motif = "| " + str(row["Motivord"]) + "\n"
        person = "| " + str(row["Personnamn / avbildad"]) + "\n"
        searchw = "| " + str(row["Sökord"]) + "\n"
        not_ok_row += link
        not_ok_row += desc
        not_ok_row += place
        not_ok_row += motif
        not_ok_row += person
        not_ok_row += searchw
        not_ok_row += "|-\n"
        not_ok_file.write(not_ok_row)
        
    
    print("New filename: {}".format(new_filename))
    print()
    print(infotext)
    print()
    print("<nowiki>\n")
    print(categories)
    print("</nowiki>")
    
    return no_content_categories

# %%
mexiko.head()
# Out:
#       Fotonummer  Postnr.          Motivord  \
# 0    0307.a.0001  2786726  karta, Stockholm
# 1  0307.a.0002.a  2786708   pyramid, tempel
# 2  0307.a.0002.b  2786732   pyramid, tempel
# 3  0307.a.0003.a  2787074   pyramid, tempel
# 4  0307.a.0003.b  2787080   pyramid, tempel
#
#                                          Beskrivning Land, foto Region, foto  \
# 0  Teotihuacans monumentalbyggnader utlagda på ka...        NaN          NaN
# 1                                      Solpyramiden.     Mexiko          NaN
# 2                                      Solpyramiden.     Mexiko          NaN
# 3                                      Solpyramiden.     Mexiko          NaN
# 4                                      Solpyramiden.     Mexiko          NaN
#
#      Ort, foto Etnisk grupp, avb. Fotodatum Personnamn / fotograf  \
# 0          NaN                NaN       NaN                   NaN
# 1  Teotihuacan                NaN      1932        Linné, Sigvald
# 2  Teotihuacan                NaN      1932        Linné, Sigvald
# 3  Teotihuacan                NaN      1932        Linné, Sigvald
# 4  Teotihuacan                NaN      1932        Linné, Sigvald
#
#   Personnamn / avbildad Sökord      Händelse / var närvarande vid  \
# 0                   NaN    NaN                                NaN
# 1                   NaN    NaN  Utgrävningar i Teotihuacan (1932)
# 2                   NaN    NaN  Utgrävningar i Teotihuacan (1932)
# 3                   NaN    NaN  Utgrävningar i Teotihuacan (1932)
# 4                   NaN    NaN  Utgrävningar i Teotihuacan (1932)
#
#                                                 Länk  \
# 0  http://kulturarvsdata.se/SMVK-EM/fotografi/htm...
# 1  http://kulturarvsdata.se/SMVK-EM/fotografi/htm...
# 2  http://kulturarvsdata.se/SMVK-EM/fotografi/htm...
# 3  http://kulturarvsdata.se/SMVK-EM/fotografi/htm...
# 4  http://kulturarvsdata.se/SMVK-EM/fotografi/htm...
#
#                                          subcol_desc  \
# 0  Teotihuacan (241) utgrävningar, fornlämningar,...
# 1  Teotihuacan (241) utgrävningar, fornlämningar,...
# 2  Teotihuacan (241) utgrävningar, fornlämningar,...
# 3  Teotihuacan (241) utgrävningar, fornlämningar,...
# 4  Teotihuacan (241) utgrävningar, fornlämningar,...
#
#                                         SMVK-EM-link
# 0    {{SMVK-EM-link|1=foto|2=2786726|3=0307.a.0001}}
# 1  {{SMVK-EM-link|1=foto|2=2786708|3=0307.a.0002.a}}
# 2  {{SMVK-EM-link|1=foto|2=2786732|3=0307.a.0002.b}}
# 3  {{SMVK-EM-link|1=foto|2=2787074|3=0307.a.0003.a}}
# 4  {{SMVK-EM-link|1=foto|2=2787080|3=0307.a.0003.b}}

# %%
mexiko = pickle.load(open("./mexiko_df_final.pickle","rb"))
#print("Loaded DataFrame from 'mexiko_df_final.pickle' OK")
filenames_file = open("./mexiko_filenames_mappings.csv","w")
filenames_file.write("Original|Commons\n")
no_content_categories = 0

not_ok_file = open("./no_ok_to_upload.info","a")
not_ok_table = ""
header_row = """{| class="wikitable sortable" style="width: 60%; height: 200px;"
        ! Image
        ! Description
        ! Place
        ! Keywords
        ! Depicted person
        ! Search terms
        |-\n"""
footer_row = "\n|}"   
not_ok_file.write(header_row)

#for row_index, row in mexiko.sample(n=20).iterrows(): #### WHEN DEVELOPING using .sample(n=20)
for row_index, row in mexiko.iterrows():
    no_content_category = create_infofiles(row, filenames_file, not_ok_file)
    no_content_categories += no_content_category
    #print("Stats: \nTotal images {}\nOK images {}\nUncategorized images {}\nImages missing author {}".format(total_images, OK_images - faulty_images, uncategorized_images, faulty_images ))
#print("Total Stats: \nTotal images {}\nOK images {}\nUncategorized images {}\nImages missing author {}".format(total_images, OK_images - faulty_images, uncategorized_images, faulty_images ))
not_ok_file.write(footer_row)
not_ok_file.close()
print("Uncategorized images: {}".format(no_content_categories))
# Out:
# Fotonummer: 0307.a.0001
# checked_fname returns:Teotihuacans_monumentalbyggnader_utlagda_på_karta_över_Stockholm_-_SMVK_-_0307.a.0001
# New filename: Teotihuacans_monumentalbyggnader_utlagda_på_karta_över_Stockholm_-_SMVK_-_0307.a.0001
#
# {{photograph
# |title              =
# |description       = {{sv|Teotihuacans monumentalbyggnader utlagda på karta över Stockholm. nan karta, Stockholm}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2786726|3=0307.a.0001}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0001.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
# [[Category:Images_from_SMVK_without_content_categories]]
# [[Category:Images_from_SMVK_without_photographer]]
# </nowiki>
# Fotonummer: 0307.a.0002.a
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0002.a
# New filename: Solpyramiden_-_SMVK_-_0307.a.0002.a
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2786708|3=0307.a.0002.a}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0002.a.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0002.b
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0002.b
# New filename: Solpyramiden_-_SMVK_-_0307.a.0002.b
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2786732|3=0307.a.0002.b}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0002.b.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0003.a
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0003.a
# New filename: Solpyramiden_-_SMVK_-_0307.a.0003.a
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787074|3=0307.a.0003.a}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0003.a.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0003.b
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0003.b
# New filename: Solpyramiden_-_SMVK_-_0307.a.0003.b
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787080|3=0307.a.0003.b}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0003.b.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0004
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0004
# New filename: Solpyramiden_-_SMVK_-_0307.a.0004
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787085|3=0307.a.0004}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0004.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0005
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0005
# New filename: Solpyramiden_-_SMVK_-_0307.a.0005
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787105|3=0307.a.0005}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0005.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0005.a
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0005.a
# New filename: Solpyramiden_-_SMVK_-_0307.a.0005.a
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787090|3=0307.a.0005.a}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0005.a.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0005.b
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0005.b
# New filename: Solpyramiden_-_SMVK_-_0307.a.0005.b
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787095|3=0307.a.0005.b}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0005.b.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0005.c
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0005.c
# New filename: Solpyramiden_-_SMVK_-_0307.a.0005.c
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787100|3=0307.a.0005.c}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0005.c.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0006
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0006
# New filename: Solpyramiden_-_SMVK_-_0307.a.0006
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787110|3=0307.a.0006}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0006.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0007
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0007
# New filename: Solpyramiden_-_SMVK_-_0307.a.0007
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787125|3=0307.a.0007}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0007.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0007.a
# checked_fname returns:Casa_administration_vid_Solpyramiden._Administrationshuset_i_Teotihuacan_-_SMVK_-_0307.a.0007.a
# New filename: Casa_administration_vid_Solpyramiden._Administrationshuset_i_Teotihuacan_-_SMVK_-_0307.a.0007.a
#
# {{photograph
# |title              =
# |description       = {{sv|Casa administration vid Solpyramiden. Administrationshuset i Teotihuacan. Fönstret längst till höger i andra våningen "vårt". I bakgrunden solpyramiden, 68 m. hög, 230 m vid basen. (katalogkort) Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787115|3=0307.a.0007.a}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0007.a.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0007.b
# checked_fname returns:Casa_administration_vid_Solpyramiden._Administrationshuset_i_Teotihuacan_-_SMVK_-_0307.a.0007.b
# New filename: Casa_administration_vid_Solpyramiden._Administrationshuset_i_Teotihuacan_-_SMVK_-_0307.a.0007.b
#
# {{photograph
# |title              =
# |description       = {{sv|Casa administration vid Solpyramiden. Administrationshuset i Teotihuacan. Fönstret längst till höger i andra våningen "vårt". I bakgrunden solpyramiden, 68 m. hög, 230 m vid basen. (katalogkort) Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787120|3=0307.a.0007.b}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0007.b.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0008.a
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0008.a
# New filename: Solpyramiden_-_SMVK_-_0307.a.0008.a
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787130|3=0307.a.0008.a}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0008.a.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0008.b
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0008.b
# New filename: Solpyramiden_-_SMVK_-_0307.a.0008.b
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787135|3=0307.a.0008.b}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0008.b.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0008.c
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0008.c
# New filename: Solpyramiden_-_SMVK_-_0307.a.0008.c
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787140|3=0307.a.0008.c}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0008.c.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0008.d
# checked_fname returns:Solpyramiden._Från_La_Ciudadela_-_SMVK_-_0307.a.0008.d
# New filename: Solpyramiden._Från_La_Ciudadela_-_SMVK_-_0307.a.0008.d
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Från "La Ciudadela". Framför denna skymtar museet och mellan detta och pyramiden administrationsbyggnaden. (katalogkort) Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787145|3=0307.a.0008.d}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0008.d.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:La_Ciudadela]]
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0008.e
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0008.e
# New filename: Solpyramiden_-_SMVK_-_0307.a.0008.e
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Den väldiga solpyramiden i Teoticuacan är, näst den svårt förstörda pyramiden i Cholula, fornamerikas största byggnadsverk. Se S. Linné: El valle y la ciudad de Mexico en 1550. Fig. 25, sid. 109. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787150|3=0307.a.0008.e}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0008.e.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0009
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0009
# New filename: Solpyramiden_-_SMVK_-_0307.a.0009
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787155|3=0307.a.0009}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0009.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0010.a
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0010.a
# New filename: Solpyramiden_-_SMVK_-_0307.a.0010.a
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787160|3=0307.a.0010.a}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0010.a.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0010.b
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0010.b
# New filename: Solpyramiden_-_SMVK_-_0307.a.0010.b
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787165|3=0307.a.0010.b}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0010.b.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0011
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0011
# New filename: Solpyramiden_-_SMVK_-_0307.a.0011
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787170|3=0307.a.0011}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0011.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0012
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0012
# New filename: Solpyramiden_-_SMVK_-_0307.a.0012
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787175|3=0307.a.0012}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0012.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0013
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0013
# New filename: Solpyramiden_-_SMVK_-_0307.a.0013
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787180|3=0307.a.0013}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0013.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0014
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0014
# New filename: Solpyramiden_-_SMVK_-_0307.a.0014
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787185|3=0307.a.0014}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0014.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0015
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0015
# New filename: Solpyramiden_-_SMVK_-_0307.a.0015
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787190|3=0307.a.0015}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0015.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0016
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0016
# New filename: Solpyramiden_-_SMVK_-_0307.a.0016
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787195|3=0307.a.0016}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0016.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0017
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0017
# New filename: Solpyramiden_-_SMVK_-_0307.a.0017
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2789107|3=0307.a.0017}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0017.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0018
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0018
# New filename: Solpyramiden_-_SMVK_-_0307.a.0018
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787205|3=0307.a.0018}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0018.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0019
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0019
# New filename: Solpyramiden_-_SMVK_-_0307.a.0019
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787210|3=0307.a.0019}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0019.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0020
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0020
# New filename: Solpyramiden_-_SMVK_-_0307.a.0020
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787215|3=0307.a.0020}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0020.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0021
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0021
# New filename: Solpyramiden_-_SMVK_-_0307.a.0021
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787220|3=0307.a.0021}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0021.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0022
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0022
# New filename: Solpyramiden_-_SMVK_-_0307.a.0022
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787225|3=0307.a.0022}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0022.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0023
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0023
# New filename: Solpyramiden_-_SMVK_-_0307.a.0023
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan pyramid, tempel}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787230|3=0307.a.0023}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0023.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0024
# checked_fname returns:Solpyramiden_-_SMVK_-_0307.a.0024
# New filename: Solpyramiden_-_SMVK_-_0307.a.0024
#
# {{photograph
# |title              =
# |description       = {{sv|Solpyramiden. Utgrävningar i Teotihuacan (1932) Teotihuacan djur, får, pyramid, tempel, åsna}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787235|3=0307.a.0024}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0024.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Donkeys_of_Mexico]]
# [[Category:Teotihuacán]]
# [[Category:Pirámide_del_Sol]]
# [[Category:Temples]]
# [[Category:Pyramids_in_Mexico]]
# </nowiki>
# Fotonummer: 0307.a.0025
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.a.0025
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.a.0025
#
# {{photograph
# |title              =
# |description       = {{sv|Teotihuacan Utgrävningar i Teotihuacan (1932) djur, får, åsna}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2787240|3=0307.a.0025}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.a.0025.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Teotihuacán]]
# [[Category:Donkeys_of_Mexico]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.a.0026
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.a.0026
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.a.0026
#
# {{photograph
# |title              =
# |description       = {{sv|Teotihuacan Utgrävningar i Teotihuacan (1932) djur, får, åsna}}
# {{en|Images from the 1932 Sigvald Linné archeological expedition at Teotihuacán, Mexico.}}
# |depicted people    =
# |depicted place     = Teotihuacan
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# ...
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0011
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0011
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0011
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800124|3=0307.g.0011}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0011.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0012
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0012
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0012
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800129|3=0307.g.0012}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0012.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0013
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0013
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0013
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800134|3=0307.g.0013}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0013.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0014
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0014
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0014
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800139|3=0307.g.0014}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0014.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0015
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0015
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0015
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800144|3=0307.g.0015}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0015.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0016
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0016
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0016
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800149|3=0307.g.0016}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0016.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0017
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0017
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0017
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800154|3=0307.g.0017}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0017.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0018
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0018
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0018
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800159|3=0307.g.0018}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0018.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0019
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0019
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0019
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800164|3=0307.g.0019}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0019.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0020
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0020
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0020
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800169|3=0307.g.0020}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0020.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0021
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0021
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0021
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800174|3=0307.g.0021}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0021.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0022
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0022
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0022
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800179|3=0307.g.0022}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0022.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0023
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0023
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0023
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800184|3=0307.g.0023}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0023.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0024
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0024
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0024
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800189|3=0307.g.0024}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0024.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0025
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0025
# New filename: Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0025
#
# {{photograph
# |title              =
# |depicted people    =
# |depicted place     = Uxmal
# |date               = 1932
# |medium             =
# |dimensions         =
# |institution        = {{Institution:Statens museer för världskultur}}
# |department         = [[d:Q1371375|Etnografiska muséet]]
# |references         =
# |object history     =
# |exhibition history =
# |credit line        =
# |inscriptions       =
# |notes              =
# |accession number   = {{SMVK-EM-link|1=foto|2=2800194|3=0307.g.0025}}
# |source             = Original file name, as receieved from SMVK:  <br /> '''0307.g.0025.tif'''
# {{SMVK_cooperation_project|COH|museum=EM}}
# |permission         = {{cc-zero}}
# |other_versions     =
# }}
#
# <nowiki>
#
# [[Category:Linné_expedition_at_Teotihuacan_Mexico_1932]]
# [[Category:Images_from_SMVK_2016-11]]
#
# [[Category:Uxmal]]
# [[Category:Images_from_SMVK_without_full_description]]
# </nowiki>
# Fotonummer: 0307.g.0026
# checked_fname returns:Utgrävningar_i_Teotihuacan_(1932)_-_SMVK_-_0307.g.0026

# %%
no_content_categories
# Out:
# 89
