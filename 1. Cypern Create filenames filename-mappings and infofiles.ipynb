# %%
import pandas as pd
from collections import Counter
import os
from textblob import TextBlob
import regex
import operator

# For bigrams creation
import nltk
from nltk import word_tokenize
from nltk.util import ngrams

# %% [raw]
# # Ensure this computer has got NLTK tokenizers
# nltk.download()

# %% [markdown]
# The metadata file on [Google Docs](https://docs.google.com/spreadsheets/d/1YXusiepersJ6_XGoUVEE0jfGh5NJs-5Rds2_l5ZbGik/edit?usp=sharing)
#
# [Here](http://cypernochkreta.dinstudio.se/text1_100.html) is a informative reference web site about the archeological excavation sites

# %% [markdown]
# # 0. Read in the metadata

# %%
def strip(text):
    try:
        return text.strip()
    except AttributeError:
        return text
    
cypern_converters = {"Fotonummer":strip,"Postnr":strip,"Nyckelord":strip,"Beskrivning":strip,"Land":strip,"foto":strip,
                     "Region, foto":strip,"Ort, foto":strip,"Geograf namn, alternativ":strip,"Fotodatum":strip,
                    "Personnamn / fotograf":strip, "Personnamn / avbildad":strip, "Sökord":strip,
                    "Händelse / var närvarande vid":strip, "Länk":strip}

cypern = pd.read_excel("excel-export.xls", sheetname="Cypern", converters=cypern_converters)

# %% [markdown]
# # 1. Create category/wikidata mapping tables

# %% [raw]
# stopwords_file = open("./stopwords.txt","w")
# for token, count in token_count.most_common(1000):
#     stopwords_file.write(token + "\n")
# stopwords_file.close()

# %%
stopwords = [w.rstrip() for w in open("./stopwords.txt").readlines()]
stopwords
# Out:
# ['i',
#  'från',
#  'och',
#  'på',
#  'in',
#  'med',
#  'vid',
#  'mot',
#  'efter',
#  '1',
#  'Från',
#  'utanför',
#  'fråga',
#  'till',
#  'av',
#  '8',
#  '14',
#  '10',
#  '11',
#  'No',
#  'en',
#  'no',
#  'nan',
#  'rummet',
#  'C',
#  '18',
#  '2',
#  'rum',
#  'I',
#  '7',
#  'J',
#  '17',
#  '16',
#  '19',
#  '22',
#  'under',
#  'fr',
#  'Före',
#  'hos',
#  'mellan',
#  'Se',
#  '15',
#  'T',
#  '53',
#  't',
#  'E',
#  'före',
#  '5',
#  '20',
#  '4',
#  '317',
#  '9',
#  'G',
#  'går',
#  'sitt',
#  '152',
#  '24',
#  '501',
#  '67',
#  '12',
#  'h',
#  '117',
#  'framför',
#  'Z',
#  '47',
#  'också',
#  'M',
#  '93',
#  '154',
#  '32',
#  '290',
#  'över',
#  '1927',
#  'allt',
#  '21',
#  'öppnad',
#  '25',
#  'allo',
#  '406',
#  'lagad',
#  'sista',
#  'VI',
#  'B',
#  's',
#  '39',
#  'sig',
#  'packar',
#  'klippt',
#  '318',
#  'sen',
#  'förbi',
#  '56',
#  'urskiljs',
#  'blir',
#  '50',
#  'del',
#  'åt',
#  '170',
#  '156',
#  'T77',
#  'sänds',
#  'man',
#  'kolla',
#  'källan',
#  'ett',
#  'framgrävande',
#  'stoppar',
#  'bergen',
#  'första',
#  'Dagen',
#  'det',
#  'Rör',
#  'T61',
#  '65',
#  'drar',
#  'lastat',
#  'L8',
#  '15899D',
#  '292',
#  'vänster',
#  '42',
#  'skick',
#  'här',
#  'Fråga',
#  'hissas',
#  'XIII',
#  '13955D',
#  'dagen',
#  'väggen',
#  'gatubild',
#  'genom',
#  '13960D',
#  'naturliga',
#  'hans',
#  '617',
#  'uppsats',
#  'ned',
#  'vänd',
#  'slutad',
#  '169',
#  'klämtar',
#  '15912D',
#  'arbete',
#  'C1',
#  'äter',
#  'flyter',
#  '129',
#  '34',
#  '13963D',
#  'diskar',
#  'Klart',
#  'använde',
#  'fotograferar',
#  'vägen',
#  'bergsryggen',
#  'Negativ',
#  'Solstrålar',
#  'Arbete',
#  'för',
#  'förer',
#  'undersöks',
#  'täckstenar',
#  '30',
#  'kranier',
#  '1930',
#  'toppen',
#  'statyanhopning',
#  'den',
#  'Reparationsarbeten',
#  'verandan',
#  'köper',
#  'trådinhägnad',
#  'Arbetarpicninc',
#  'hitåt',
#  'Ödsligt',
#  'hacka',
#  'grottöppningen',
#  'snö',
#  '13965D',
#  'kontorsfönstret',
#  'rutorna',
#  '122',
#  'herdar',
#  'trappan',
#  'halt',
#  '1998',
#  'om',
#  'lagret',
#  '123',
#  'Exteriör',
#  'Arbetet',
#  'läggs',
#  'tänder',
#  'skriver',
#  'pärlor',
#  '1740',
#  'stass',
#  'Punktering',
#  '98',
#  'Kvinna',
#  'Så',
#  'fest',
#  'serie',
#  'lagar',
#  'Middagsrast',
#  '107',
#  'N520',
#  'tegelmuren',
#  'djupgrävning',
#  'vin',
#  'W',
#  'simmar',
#  'fel',
#  'II',
#  '69',
#  'fl',
#  'julklappsutdelning',
#  'Arbetarna',
#  'Nattligt',
#  'mosaikgolv',
#  'västmuren',
#  'substruktionsmurarna',
#  'hopsatt',
#  'jordprofiler',
#  'uppstigningen',
#  'grotta',
#  'jubileét',
#  'Kaffepaus',
#  'Flyttning',
#  'mitten',
#  'kammartaket',
#  'reklambild',
#  '13964D',
#  'Maskeraden',
#  'sanden',
#  'månskens',
#  'cementgolvet',
#  'oöppnad',
#  'vattenprov',
#  'scenens',
#  'uppifrån',
#  'gällande',
#  'Hyddan',
#  'Kylistra',
#  '602',
#  '306',
#  'Sista',
#  'frukost',
#  '438',
#  'upp',
#  'kostym',
#  'brasan',
#  'Kalas',
#  'knä',
#  'topp',
#  'Stenhuset',
#  'Festmåltid',
#  'Utställningsvy',
#  'Ett',
#  'regn',
#  'Krogbild',
#  'Palatsägaren',
#  'Kruktabellen',
#  'Boplatsen',
#  'bottenstratum',
#  'börjas',
#  'gräver',
#  'Profilkors',
#  '23',
#  'tälten',
#  'm',
#  'gör',
#  'övre',
#  'avvägningsinstrumentet',
#  'graven',
#  'Bypolis',
#  'X',
#  '409',
#  'utgrävda',
#  'Jordgrav',
#  'fingräver',
#  '6',
#  'Cementgolvet',
#  'Tälten',
#  'ryggen',
#  'vattenränna',
#  'fotografisk',
#  'murar',
#  '37',
#  'tider',
#  'salongen',
#  'kommer',
#  'inom',
#  'grävningarna',
#  'Nedre',
#  'Hinkning',
#  'som',
#  'kontor',
#  'Fåraherde',
#  'korsande',
#  'Delar',
#  'även',
#  'son',
#  'Arbetsstyrkan',
#  'bilen',
#  'resten',
#  'rakar',
#  'Slakt',
#  '1728',
#  'En',
#  'sönderblåsta',
#  'praktrum',
#  'Skrivbordsröra',
#  'akropolens',
#  'pick',
#  'avväger',
#  'Situationsbild',
#  'Musik',
#  '702',
#  '59',
#  'höstregnet',
#  '13',
#  'Okänd',
#  '311',
#  'Till',
#  '94',
#  'Sågning',
#  'efterbegravning',
#  'NO',
#  'Altare',
#  'Färd',
#  'period',
#  'Skämt',
#  '319',
#  'N',
#  'tvärprofilen',
#  'tjänsterum',
#  'cementgolv',
#  'Mynningen',
#  'östsluttningen',
#  'Första',
#  'säd',
#  'mat',
#  'på',
#  'Utställning',
#  'Grav',
#  'Svenska',
#  'Teatern',
#  'Fältritning',
#  'Arbetsbild',
#  'Cypernexpeditionen',
#  't.v',
#  't.h.',
#  'interiör',
#  'situ',
#  'Helhetsbild',
#  'institutet',
#  'väster',
#  'öster',
#  'norr',
#  'söder',
#  '1933']

# %% [markdown]
# ## Column "Nyckelord"

# %%
list_of_strings = cypern.Nyckelord.values.astype("str")
chunk_of_strings = "" 

for string in list_of_strings:
    clean_string = regex.sub("[\"\'\.\!\?\:,;]| - ","",string) # remove .'s
    chunk_of_strings += " " + clean_string

chunk_of_strings # separated by ","

nyckelord_list = [phrase.strip() for phrase in chunk_of_strings.split(" ")]
#print(nyckelord_list[:10])

nyckelord_freq = Counter(nyckelord_list)
nyckelord_freq.most_common(20)
# Out:
# [('Svenska', 612),
#  ('Cypernexpeditionen', 612),
#  ('utgrävning', 59),
#  ('utställning', 29),
#  ('interiör', 29),
#  ('exteriör', 23),
#  ('arkeologi', 21),
#  ('ritning', 19),
#  ('staty', 11),
#  ('porträtt', 7),
#  ('gruppbild', 5),
#  ('bad', 4),
#  ('keramik', 3),
#  ('barn', 3),
#  ('bord', 3),
#  ('präst', 2),
#  ('kalksten', 2),
#  ('tält', 2),
#  ('väg', 2),
#  ('kamel', 2)]

# %% [markdown]
# The mapping tables are pasted onto [Commons](https://commons.wikimedia.org/wiki/Commons:Medelhavsmuseet/batchUploads/Cypern_keywords)

# %%
header = "== Keywords from column '''Nyckelord''' (as is, separated by comma) ==\n"
header_row = """{| class="wikitable sortable" style="width: 60%; height: 200px;"
! Nyckelord
! frequency
! category
! wikidata
|-\n"""

data_rows = []
for kw, count in  nyckelord_freq.most_common(50): # original 12 stops at 4 occurances of "bad"
    nyckelord = "| " + kw + "\n"
    
    freq = "| " + str(count) + "\n"
    the_rest = "| \n| \n|-"
        
    row = nyckelord + freq + the_rest
    
    data_rows.append(row)
        
table_ending = "\n|}"
#print(data_rows)
nyckelord_wikitable = header + header_row + "\n".join(data_rows) + table_ending
print(nyckelord_wikitable)
# Out:
# == Keywords from column '''Nyckelord''' (as is, separated by comma) ==
# {| class="wikitable sortable" style="width: 60%; height: 200px;"
# ! Nyckelord
# ! frequency
# ! category
# ! wikidata
# |-
# | Svenska
# | 612
# |
# |
# |-
# | Cypernexpeditionen
# | 612
# |
# |
# |-
# | utgrävning
# | 59
# |
# |
# |-
# | utställning
# | 29
# |
# |
# |-
# | interiör
# | 29
# |
# |
# |-
# | exteriör
# | 23
# |
# |
# |-
# | arkeologi
# | 21
# |
# |
# |-
# | ritning
# | 19
# |
# |
# |-
# | staty
# | 11
# |
# |
# |-
# | porträtt
# | 7
# |
# |
# |-
# | gruppbild
# | 5
# |
# |
# |-
# | bad
# | 4
# |
# |
# |-
# | keramik
# | 3
# |
# |
# |-
# | barn
# | 3
# |
# |
# |-
# | bord
# | 3
# |
# |
# |-
# | präst
# | 2
# |
# |
# |-
# | kalksten
# | 2
# |
# |
# |-
# | tält
# | 2
# |
# |
# |-
# | väg
# | 2
# |
# |
# |-
# | kamel
# | 2
# |
# |
# |-
# | kista
# | 2
# |
# |
# |-
# | skelett
# | 2
# |
# |
# |-
# |
# | 1
# |
# |
# |-
# | kranium
# | 1
# |
# |
# |-
# | kärl
# | 1
# |
# |
# |-
# | nan
# | 1
# |
# |
# |-
# | relief
# | 1
# |
# |
# |-
# | träd
# | 1
# |
# |
# |-
# | landskap
# | 1
# |
# |
# |-
# | huvud
# | 1
# |
# |
# |-
# | brynja
# | 1
# |
# |
# |-
# | tjur
# | 1
# |
# |
# |-
# | kamera
# | 1
# |
# |
# |-
# | karta
# | 1
# |
# |
# |-
# | kruka
# | 1
# |
# |
# |-
# | vattenpipa
# | 1
# |
# |
# |-
# | lampa
# | 1
# |
# |
# |-
# | fest
# | 1
# |
# |
# |-
# | vilstol
# | 1
# |
# |
# |-
# | mosaik
# | 1
# |
# |
# |-
# |}

# %% [markdown]
# ## Column "Beskrivning"

# %%
####### Unigrams ##############
clean_tokens_list = []
mega_string = ""
list_of_strings = []
for string in cypern.Beskrivning.values.astype("str"):
    mega_string += " " +string
    clean_string = regex.sub("[\"\'\.\!\?\:\,;]| - ","",string) # remove .'s
    #print(clean_string)
    tokens = clean_string.split(" ")
    clean_tokens = [word for word in tokens if word not in stopwords]
    #print(clean_tokens)
    for token in clean_tokens:
        clean_tokens_list.append(token)
    clean_string = " ".join(clean_tokens)
    clean_ended_string = clean_string + "." # add .'s again!

    list_of_strings.append(clean_ended_string)
    
#print("clean_tokens_list:\n{}".format(clean_tokens_list))
token_count = Counter(clean_tokens_list)
print("Token count:\n{}".format(token_count.most_common(50)))

####### Bigrams ##############
chunk_of_strings = "" 
chunk_of_strings += list_of_strings[0]
for string in list_of_strings[1:]:
    chunk_of_strings += " " + string
#print(chunk_of_strings)


### bigrams initial approach
#blob = TextBlob(chunk_of_strings) # initiate empty blob

#bigrams = blob.ngrams(2)
#bigrams_list = []
#for wl in bigrams:
#    bigrams_list.append(" ".join(wl))

#bigrams_count = Counter(bigrams_list)
#print("Bigrams:\n{}".format(bigrams_count.most_common(50)))
#print()

### Bigrams second approach (to avoid bigrams made of end-word + first word next sentence)
token = nltk.word_tokenize(mega_string)
bigrams = ngrams(token,2)
bigrams_counter = Counter(bigrams)

clean_bigram_dict = {}
for each_tuple, freq in bigrams_counter.items():
    #print(each_tuple)
    w1, w2 = each_tuple
    forbidden_chars = set([",","."])
    if w1 in forbidden_chars or w2 in forbidden_chars:
        continue
    elif freq > 3:
        clean_bigram_dict[w1 + " " + w2] = freq
    else:
        continue
#print(type(bigrams_counter))
#print(list(bigrams_counter)[:2])
sorted_clean_bigram_dict = sorted(clean_bigram_dict.items(), key=operator.itemgetter(1), reverse=True)
print("Bigrams:\n{}".format(sorted_clean_bigram_dict))
#for bigram in sorted_clean_bigram_dict:
#    print(bigram)

# single words
# Out:
# clean_tokens_list:
# ['Sektion', 'IV', 'Profil', 'D', 'Skala', '120', 'Sammansatt', 'bild', '13955D13958D', 'Sektion', 'V', 'Profil', 'Sektion', 'Profil', 'H', 'Skala', '120', 'Sammansatt', 'bild', '13960D-', 'Sektion', 'Profil', 'Skala', '120', 'Sammansatt', 'bild', 'Ajia', 'Irini', 'Ajia', 'Irini', 'Ajia', 'Irini', 'Ajia', 'Irini', 'Ajia', 'Irini', 'Ajia', 'Irini', 'Ajia', 'Irini', 'Ajia', 'Irini', 'Ajia', 'Irini', 'Ajia', 'Irini', 'Ajia', 'Irini', 'Ajia', 'Irini', 'Ajia', 'Irini', 'Sammansatt', 'bild', 'Ajia', 'Irini', '15899D15912D', 'Grävningstillstånd', 'områden', 'Pera', 'Khorio', 'Dali', 'Narghilé-rökning', 'Alfred', 'Westholm', 'Vivi', 'Gjerstad', 'Kyrenia', 'Badstranden', 'Kyrenia', 'Erik', 'Sjöqvist', 'grav', 'Lapithos', 'dromos', 'Lapithos', 'Lapithos', 'landskapsbild', '409/94', 'Landskapsbild', 'A', 'gravfynd', 'Lapithos', 'Erik', 'Sjöqvist', 'Nicosia', 'Evagoras', 'östra', 'parados', 'Soli', 'Bysantinska', 'Soli', 'östra', 'eisodos', 'Soli', 'orkestran', 'Soli', 'proskenions', 'Soli', 'III', 'östra', 'scenhörnet', 'Soli', 'Toulis', 'stranden', 'Soli', 'Stora', 'profilen', 'Terr', 'III', 'Soli', 'Skulptur', 'Alfred', 'Westholm', 'konserverar', 'krukor', 'Nicosia', 'Lapithos', 'arbetsbild', 'Lapithos', '406/65', 'Alfred', 'Westholm', 'dromos', 'Milia', 'Milia', 'landskap', 'Fokas', 'kapell', 'bakgrunden', 'Milia', 'dromos', 'Milia', 'Einar', 'Gjerstad', 'Nicosia', 'John', 'Lindros', 'Nicosia', 'dromos', 'Lapithos', 'dromos', 'Lapithos', 'Lapithos', 'Kafenion', 'Kalavasos', 'Christoforos', 'Kafenion', 'Erik', 'Sjöqvist', 'John', 'Lindros', 'bakgrunden', 'Rosa', 'Lindros', 'tv', 'vit', 'hatt', 'borgmästare', 'Kaplanis', 'Dimitrakis', 'Lapithos', 'Erik', 'Sjöqvist', 'Lapithos', 'Toppterrassen', 'templet', 'Soli', 'Monasteraki', 'kolonn', 'kapitäl', 'Soli', 'Soli', 'dans', 'orkestran', 'Soli', 'dans', 'orkestran', 'Soli', 'orkestran', 'Soli', 'Torget', 'Volvo', '', 'Polis', 'Volvo', 'Marion', 'Översiktsbild', 'Gunnis', 'grävning', 'Sydvästsluttningen', 'Vouni', 'Vouni', 'Familjen', 'Gjerstad', 'Vouni', 'Kristos', 'Westholm', 'Lazaros', 'Vouni', 'Frukost', 'Vouni', 'Vouni', 'Athenatemplet', 'genombrytningen', 'golvet', 'Vouni', 'Vouni', 'Palatset', 'Vouni', 'Mavro', 'Keratas', 'Vouni', 'Badstranden', 'John', 'Lindros', 'Vouni', 'Festgeten', 'slaktas', 'Vouni', 'Badstranden', 'Vouni', 'huggningar', 'taket', 'Vouni', 'åskväder', 'Vouni', 'Palatskullen', 'utgrävningen', 'Vouni', 'Rum', 'Vouni', 'Vouni', 'Rum', 'ruta', 'statyer', 'Vouni', 'Solis', 'akropol', 'Vouni', 'Athenatemplet', 'Vouni', 'Eleni', 'Vouni', 'Charalampos', '”korouan”', 'Vouni', 'Stefan', 'Gjerstad', 'huset', 'Vouni', 'Gjerstad', 'Westholm', 'dricker', 'te', 'Vouni', 'Vouni', 'Vivi', 'Gjerstad', 'Charoupiaträdet', 'Vouni', 'Interiör', 'huset', 'Vouni', 'Eleni', 'köket', 'Vouni', 'östra', 'ingången', 'Alfred', 'Westholm', 'Soli', 'fasad', 'Alfred', 'Westholm', 'Soli', 'orkestran', 'cavean', 'Alfred', 'Westholm', 'Soli', 'Festgeten', 'slaktas', 'Soli', 'Festgeten', 'stekes', 'Soli', 'Pezoullia', 'provschakt', 'detalj', 'Soli', 'Pezoullia', 'provschakt', 'Soli', 'Soli', 'Galini', 'Rum', 'Guldskatten', 'situVouni', 'husbygget', 'Vouni', 'Vouni', 'Martin', 'Gjerstad', 'Lazaros', 'Vouni', 'Volvo', 'kaféet', 'Pyrgos', 'Festgeten', 'stekes', 'Galini', 'Galini', 'Galini', 'Muktarens', 'Milia', 'Muktaren', 'fru', 'Ajios', 'Jakovos', 'Ajios', 'Jakovos', 'Kameler', 'lastas', 'keramiklådor', 'Milia', 'Kameler', 'lastas', 'keramiklådor', 'Milia', 'gravberget', 'Vouni', 'Westholm', 'Lindros', 'tältet', 'Vouni', 'Koundouras', 'kleftika', 'Soli', 'Landskap', 'Oura', 'Oura', 'Polisen', 'Oura', 'Trachonas', 'T1', 'Trachonas', 'T1', 'dromos', 'relief', 'Trachonas', 'Oura', 'Plakes', 'arbetsbild', 'Lapithos', 'Lapithos', 'Plakes', 'landskapsbild', 'Lapithos', 'Plakes', 'landskapsbild', 'Plakes', 'EC-huset', 'Lapithos', 'Lapitos', 'Grävningsplatsen', 'Ajia', 'Anastasia', 'Avfärden', 'Lapithos', 'Avfärden', 'Lapithos', 'Lapithos', 'lanskapsbild', 'Lapithos', 'Badstranden', 'Lambousa', 'Dansen', 'Ma ...
# Token count:
# [('Vouni', 97), ('Stockholm', 55), ('Ajia', 49), ('Irini', 47), ('Soli', 47), ('Nicosia', 40), ('Westholm', 38), ('Marion', 38), ('Alfred', 35), ('Erik', 35), ('Gjerstad', 34), ('Sjöqvist', 32), ('Lapithos', 32), ('Lindros', 28), ('Amathus', 26), ('Idalion', 25), ('John', 23), ('Jakovos', 19), ('Ajios', 19), ('Liljevalchs', 19), ('Mersinaki', 19), ('Konsthall', 19), ('Einar', 19), ('Kition', 18), ('dromos', 18), ('Rum', 15), ('Kythrea', 14), ('Cholades', 13), ('Utsikt', 13), ('utgrävningen', 12), ('grav', 11), ('Volvo', 10), ('Milia', 10), ('Vivi', 10), ('Galini', 9), ('Macheras', 9), ('Oura', 9), ('', 8), ('fynd', 8), ('östra', 8), ('Fylleri', 8), ('K', 8), ('Petra', 7), ('Panajiotis', 7), ('Souidos', 7), ('Nitovikla', 6), ('III', 6), ('L', 6), ('Limniti', 6), ('H', 6)]
# Bigrams:
# [('Svenska Cypernexpeditionen', 581), ('Cypernexpeditionen Grav', 56), ('Ajia Irini', 47), ('Alfred Westholm', 35), ('Erik Sjöqvist', 32), ('in situ', 30), ('Vouni Svenska', 29), ('Stockholm Svenska', 27), ('John Lindros', 21), ('Ajios Jakovos', 19), ('Liljevalchs Konsthall', 19), ('Utställning på', 19), ('på Liljevalchs', 19), ('Cypernexpeditionen Teatern', 18), ('Einar Gjerstad', 17), ('Cypernexpeditionen Erik', 16), ('Soli Svenska', 15), ('Cypernexpeditionen Utställning', 15), ('Cypernexpeditionen Arbetsbild', 14), ('Cypernexpeditionen Amathus', 12), ('Cypernexpeditionen Lapithos', 12), ('Cypernexpeditionen Cholades', 12), ('Cypernexpeditionen John', 11), ('från väster', 10), ('Sjöqvist och', 10), ('Cypernexpeditionen fråga', 10), ('Cypernexpeditionen Alfred', 10), ('Konsthall 1933', 10), ('Amathus Svenska', 9), ('Nicosia Svenska', 9), ('Vivi Gjerstad', 9), ('Cypernexpeditionen Einar', 9), ('Cypernexpeditionen Svenska', 8), ('från öster', 8), ('Svenska institutet', 8), ('fynd in', 8), ('och Alfred', 8), ('Cypernexpeditionen Rum', 7), ('Cypernexpeditionen Souidos', 7), ('Utsikt mot', 7), ('Cypernexpeditionen Vouni', 7), ('efter utgrävningen', 7), ('Cypernexpeditionen Marion', 6), ('Cypernexpeditionen Ruta', 6), ('i rum', 6), ('Petra Tou', 6), ('Cypernexpeditionen Från', 6), ('Tou Limniti', 6), ('Westholm och', 6), ('Ruta L', 5), ('Cypernexpeditionen Utsikt', 5), ('Utställning ”Före', 5), ('”Före Fidias”', 5), ('Cypernexpeditionen Vivi', 5), ('Grav 14', 5), ('Rosa Lindros', 5), ('Grav 22', 5), ('från norr', 5), ('och Einar', 5), ('fyndlagret in', 4), ('på terrassen', 4), ('på orkestran', 4), ('Cypernexpeditionen Volvo', 4), ('från nordväst', 4), ('Cypernexpeditionen Avskedsfesten', 4), ('med fynd', 4), ('Cypernexpeditionen Cypernsamlingen', 4), ('Avskedsfesten hos', 4), ('Cypernexpeditionen Grottan', 4), ('vid Fylleri', 4), ('från sydväst', 4), ('Cypernexpeditionen Helhetsbild', 4), ('Grav 11', 4), ('Cypernexpeditionen Lapitos', 4), ('Livet på', 4), ('från söder', 4), ('Sammansatt bild', 4), ('nan nan', 4), ('Profil mellan', 4), ('Grav 2', 4), ('Grav 53', 4), ('Stefan Gjerstad', 4), ('Cypernexpeditionen Kameler', 4), ('Grav 16', 4), ('Palatset från', 4), ('Cypernexpeditionen Kythrea', 4), ('Grottan vid', 4), ('Westholm vid', 4), ('Cypernexpeditionen Badstranden', 4), ('Cypernexpeditionen Festgeten', 4), ('Cypernexpeditionen Kition', 4), ('hos Panajiotis', 4), ('Cypernexpeditionen Kristos', 4), ('Cypernexpeditionen Skulptur', 4)]

# %%
header = "== Keywords from column '''Beskrivning''' (två-ordskombinationer) ==\n"
header_row = """{| class="wikitable sortable" style="width: 60%; height: 200px;"
! Två-ordskombination
! frequency
! category
! wikidata
|-\n"""

data_rows = []
for kw, count in sorted_clean_bigram_dict: # original stops at 3 occurances
    nyckelord = "| " + kw + "\n"
    
    freq = "| " + str(count) + "\n"
    the_rest = "| \n| \n|-"
        
    row = nyckelord + freq + the_rest
    
    data_rows.append(row)
        
table_ending = "\n|}"
#print(data_rows)
nyckelord_wikitable = header + header_row + "\n".join(data_rows) + table_ending
print(nyckelord_wikitable)
# Out:
# == Keywords from column '''Beskrivning''' (två-ordskombinationer) ==
# {| class="wikitable sortable" style="width: 60%; height: 200px;"
# ! Två-ordskombination
# ! frequency
# ! category
# ! wikidata
# |-
# | Svenska Cypernexpeditionen
# | 581
# |
# |
# |-
# | Cypernexpeditionen Grav
# | 56
# |
# |
# |-
# | Ajia Irini
# | 47
# |
# |
# |-
# | Alfred Westholm
# | 35
# |
# |
# |-
# | Erik Sjöqvist
# | 32
# |
# |
# |-
# | in situ
# | 30
# |
# |
# |-
# | Vouni Svenska
# | 29
# |
# |
# |-
# | Stockholm Svenska
# | 27
# |
# |
# |-
# | John Lindros
# | 21
# |
# |
# |-
# | Liljevalchs Konsthall
# | 19
# |
# |
# |-
# | Ajios Jakovos
# | 19
# |
# |
# |-
# | på Liljevalchs
# | 19
# |
# |
# |-
# | Utställning på
# | 19
# |
# |
# |-
# | Cypernexpeditionen Teatern
# | 18
# |
# |
# |-
# | Einar Gjerstad
# | 17
# |
# |
# |-
# | Cypernexpeditionen Erik
# | 16
# |
# |
# |-
# | Cypernexpeditionen Utställning
# | 15
# |
# |
# |-
# | Soli Svenska
# | 15
# |
# |
# |-
# | Cypernexpeditionen Arbetsbild
# | 14
# |
# |
# |-
# | Cypernexpeditionen Cholades
# | 12
# |
# |
# |-
# | Cypernexpeditionen Amathus
# | 12
# |
# |
# |-
# | Cypernexpeditionen Lapithos
# | 12
# |
# |
# |-
# | Cypernexpeditionen John
# | 11
# |
# |
# |-
# | Sjöqvist och
# | 10
# |
# |
# |-
# | Cypernexpeditionen Alfred
# | 10
# |
# |
# |-
# | Cypernexpeditionen fråga
# | 10
# |
# |
# |-
# | Konsthall 1933
# | 10
# |
# |
# |-
# | från väster
# | 10
# |
# |
# |-
# | Amathus Svenska
# | 9
# |
# |
# |-
# | Nicosia Svenska
# | 9
# |
# |
# |-
# | Vivi Gjerstad
# | 9
# |
# |
# |-
# | Cypernexpeditionen Einar
# | 9
# |
# |
# |-
# | från öster
# | 8
# |
# |
# |-
# | fynd in
# | 8
# |
# |
# |-
# | Svenska institutet
# | 8
# |
# |
# |-
# | Cypernexpeditionen Svenska
# | 8
# |
# |
# |-
# | och Alfred
# | 8
# |
# |
# |-
# | Utsikt mot
# | 7
# |
# |
# |-
# | efter utgrävningen
# | 7
# |
# |
# |-
# | Cypernexpeditionen Souidos
# | 7
# |
# |
# |-
# | Cypernexpeditionen Rum
# | 7
# |
# |
# |-
# | Cypernexpeditionen Vouni
# | 7
# |
# |
# |-
# | Cypernexpeditionen Marion
# | 6
# |
# |
# |-
# | Cypernexpeditionen Ruta
# | 6
# |
# |
# |-
# | Westholm och
# | 6
# |
# |
# |-
# | Tou Limniti
# | 6
# |
# |
# |-
# | i rum
# | 6
# |
# |
# |-
# | Cypernexpeditionen Från
# | 6
# |
# |
# |-
# | Petra Tou
# | 6
# |
# |
# |-
# | Grav 22
# | 5
# |
# |
# |-
# | Cypernexpeditionen Utsikt
# | 5
# |
# |
# |-
# | Cypernexpeditionen Vivi
# | 5
# |
# |
# |-
# | ”Före Fidias”
# | 5
# |
# |
# |-
# | Grav 14
# | 5
# |
# |
# |-
# | Rosa Lindros
# | 5
# |
# |
# |-
# | Ruta L
# | 5
# |
# |
# |-
# | och Einar
# | 5
# |
# |
# |-
# | från norr
# | 5
# |
# |
# |-
# | Utställning ”Före
# | 5
# |
# |
# |-
# | Cypernexpeditionen Grottan
# | 4
# |
# |
# |-
# | Cypernexpeditionen Kameler
# | 4
# |
# |
# |-
# | med fynd
# | 4
# |
# |
# |-
# | Cypernexpeditionen Helhetsbild
# | 4
# |
# |
# |-
# | från söder
# | 4
# |
# |
# |-
# | Cypernexpeditionen Badstranden
# | 4
# |
# |
# |-
# | Grottan vid
# | 4
# |
# |
# |-
# | fyndlagret in
# | 4
# |
# |
# |-
# | Westholm vid
# | 4
# |
# |
# |-
# | Stefan Gjerstad
# | 4
# |
# |
# |-
# | nan nan
# | 4
# |
# |
# |-
# | från nordväst
# | 4
# |
# |
# |-
# | Cypernexpeditionen Kythrea
# | 4
# |
# |
# |-
# | Grav 53
# | 4
# |
# |
# |-
# | vid Fylleri
# | 4
# |
# |
# |-
# | Avskedsfesten hos
# | 4
# |
# |
# |-
# | Grav 16
# | 4
# |
# |
# |-
# | Grav 2
# | 4
# |
# |
# |-
# | Cypernexpeditionen Cypernsamlingen
# | 4
# |
# |
# |-
# | på terrassen
# | 4
# |
# |
# |-
# | på orkestran
# | 4
# |
# |
# |-
# | Profil mellan
# | 4
# |
# |
# |-
# | hos Panajiotis
# | 4
# |
# |
# |-
# | Cypernexpeditionen Lapitos
# | 4
# |
# |
# |-
# | Cypernexpeditionen Avskedsfesten
# | 4
# |
# |
# |-
# | Cypernexpeditionen Kition
# | 4
# |
# |
# |-
# | Palatset från
# | 4
# |
# |
# |-
# | Sammansatt bild
# | 4
# |
# |
# |-
# | från sydväst
# | 4
# |
# |
# |-
# | Cypernexpeditionen Festgeten
# | 4
# |
# |
# |-
# | Grav 11
# | 4
# |
# |
# |-
# | Cypernexpeditionen Kristos
# | 4
# |
# |
# |-
# | Cypernexpeditionen Skulptur
# | 4
# |
# |
# |-
# | Cypernexpeditionen Volvo
# | 4
# |
# |
# |-
# | Livet på
# | 4
# |
# |
# |-
# |}

# %%
header = "== Keywords from column '''Beskrivning''' (word-by-word) ==\n"
header_row = """{| class="wikitable sortable" style="width: 60%; height: 200px;"
! Ord
! frequency
! category
! wikidata
|-\n"""

data_rows = []
for kw, count in token_count.most_common(50): # stops at 3 occurances
    nyckelord = "| " + kw + "\n"
    
    freq = "| " + str(count) + "\n"
    the_rest = "| \n| \n|-"
        
    row = nyckelord + freq + the_rest
    
    data_rows.append(row)
        
table_ending = "\n|}"
#print(data_rows)
nyckelord_wikitable = header + header_row + "\n".join(data_rows) + table_ending
print(nyckelord_wikitable)
# Out:
# == Keywords from column '''Beskrivning''' (word-by-word) ==
# {| class="wikitable sortable" style="width: 60%; height: 200px;"
# ! Ord
# ! frequency
# ! category
# ! wikidata
# |-
# | Vouni
# | 97
# |
# |
# |-
# | Stockholm
# | 55
# |
# |
# |-
# | Ajia
# | 49
# |
# |
# |-
# | Irini
# | 47
# |
# |
# |-
# | Soli
# | 47
# |
# |
# |-
# | Nicosia
# | 40
# |
# |
# |-
# | Marion
# | 38
# |
# |
# |-
# | Westholm
# | 38
# |
# |
# |-
# | Erik
# | 35
# |
# |
# |-
# | Alfred
# | 35
# |
# |
# |-
# | Gjerstad
# | 34
# |
# |
# |-
# | Sjöqvist
# | 32
# |
# |
# |-
# | Lapithos
# | 32
# |
# |
# |-
# | Lindros
# | 28
# |
# |
# |-
# | Amathus
# | 26
# |
# |
# |-
# | Idalion
# | 25
# |
# |
# |-
# | John
# | 23
# |
# |
# |-
# | Mersinaki
# | 19
# |
# |
# |-
# | Jakovos
# | 19
# |
# |
# |-
# | Einar
# | 19
# |
# |
# |-
# | Liljevalchs
# | 19
# |
# |
# |-
# | Konsthall
# | 19
# |
# |
# |-
# | Ajios
# | 19
# |
# |
# |-
# | dromos
# | 18
# |
# |
# |-
# | Kition
# | 18
# |
# |
# |-
# | Rum
# | 15
# |
# |
# |-
# | Kythrea
# | 14
# |
# |
# |-
# | Utsikt
# | 13
# |
# |
# |-
# | Cholades
# | 13
# |
# |
# |-
# | utgrävningen
# | 12
# |
# |
# |-
# | grav
# | 11
# |
# |
# |-
# | Vivi
# | 10
# |
# |
# |-
# | Milia
# | 10
# |
# |
# |-
# | Volvo
# | 10
# |
# |
# |-
# | Galini
# | 9
# |
# |
# |-
# | Macheras
# | 9
# |
# |
# |-
# | Oura
# | 9
# |
# |
# |-
# |
# | 8
# |
# |
# |-
# | Fylleri
# | 8
# |
# |
# |-
# | östra
# | 8
# |
# |
# |-
# | fynd
# | 8
# |
# |
# |-
# | K
# | 8
# |
# |
# |-
# | Panajiotis
# | 7
# |
# |
# |-
# | Souidos
# | 7
# |
# |
# |-
# | Petra
# | 7
# |
# |
# |-
# | Enkomi
# | 6
# |
# |
# |-
# | huset
# | 6
# |
# |
# |-
# | Nitovikla
# | 6
# |
# |
# |-
# | fyndlagret
# | 6
# |
# |
# |-
# | H
# | 6
# |
# |
# |-
# |}

# %% [markdown]
# ## Merge keywords from columns Nyckelord and Beskrivning

# %%
tot_dict = {}
for bigram, count in bigrams_count.most_common(100):
    tot_dict[bigram] = count
for unigram, count in token_count.most_common(100):
    tot_dict[unigram] = count
sorted_tot_dict = sorted(tot_dict.items(), key=operator.itemgetter(1), reverse=True)
sorted_tot_dict
# Out:
# [('Vouni', 97),
#  ('Stockholm', 55),
#  ('Ajia', 49),
#  ('Irini', 47),
#  ('Soli', 47),
#  ('Ajia Irini', 47),
#  ('Nicosia', 40),
#  ('Marion', 38),
#  ('Westholm', 38),
#  ('Erik', 35),
#  ('Alfred Westholm', 35),
#  ('Alfred', 35),
#  ('Gjerstad', 34),
#  ('Sjöqvist', 32),
#  ('Erik Sjöqvist', 32),
#  ('Lapithos', 32),
#  ('Lindros', 28),
#  ('Amathus', 26),
#  ('Idalion', 25),
#  ('John', 23),
#  ('John Lindros', 21),
#  ('Liljevalchs Konsthall', 19),
#  ('Liljevalchs', 19),
#  ('Mersinaki', 19),
#  ('Einar', 19),
#  ('Ajios', 19),
#  ('Jakovos', 19),
#  ('Ajios Jakovos', 19),
#  ('Irini Ajia', 19),
#  ('Konsthall', 19),
#  ('Kition', 18),
#  ('dromos', 18),
#  ('Einar Gjerstad', 17),
#  ('Rum', 15),
#  ('Kythrea', 14),
#  ('Utsikt', 13),
#  ('Cholades', 13),
#  ('utgrävningen', 12),
#  ('Marion Marion', 12),
#  ('Vouni Vouni', 11),
#  ('grav', 11),
#  ('Vivi', 10),
#  ('Volvo', 10),
#  ('Milia', 10),
#  ('Soli Cholades', 9),
#  ('Galini', 9),
#  ('Macheras', 9),
#  ('Vivi Gjerstad', 9),
#  ('Oura', 9),
#  ('Stockholm Liljevalchs', 9),
#  ('Konsthall Liljevalchs', 9),
#  ('', 8),
#  ('Amathus Amathus', 8),
#  ('fynd', 8),
#  ('K', 8),
#  ('Cholades Rum', 8),
#  ('östra', 8),
#  ('Fylleri', 8),
#  ('Panajiotis', 7),
#  ('Petra', 7),
#  ('dromos Marion', 7),
#  ('Souidos', 7),
#  ('Lapithos Lapithos', 7),
#  ('Nicosia Nicosia', 6),
#  ('Enkomi', 6),
#  ('Tou Limniti', 6),
#  ('Limniti', 6),
#  ('Ruta', 6),
#  ('L', 6),
#  ('Petra Tou', 6),
#  ('III', 6),
#  ('huset', 6),
#  ('Tou', 6),
#  ('Frv', 6),
#  ('H', 6),
#  ('Nitovikla', 6),
#  ('arbetsbild', 6),
#  ('Amathus fyndlagret', 6),
#  ('fyndlagret', 6),
#  ('Sjöqvist Alfred', 5),
#  ('Ruta L', 5),
#  ('Fidias”', 5),
#  ('stora', 5),
#  ('Marion dromos', 5),
#  ('bild', 5),
#  ('Palatset', 5),
#  ('Atterman', 5),
#  ('Grottan Fylleri', 5),
#  ('Stylli', 5),
#  ('Rosa', 5),
#  ('Skulptur', 5),
#  ('Kythrea Grottan', 5),
#  ('”Före', 5),
#  ('Cypernsamlingen', 5),
#  ('Kristos', 5),
#  ('Paleoskoutella', 5),
#  ('Grottan', 5),
#  ('”Före Fidias”', 5),
#  ('Vouni Utsikt', 5),
#  ('detalj', 5),
#  ('Idalion Idalion', 5),
#  ('Lazaros', 5),
#  ('nordväst', 5),
#  ('V', 5),
#  ('Irini Ruta', 5),
#  ('orkestran', 5),
#  ('Kerynia', 5),
#  ('Rosa Lindros', 5),
#  ('Gjerstad Nicosia', 4),
#  ('Panajiotis Idalion', 4),
#  ('Macheras Livet', 4),
#  ('Vouni Rum', 4),
#  ('Profil', 4),
#  ('Jordprofil', 4),
#  ('Vouni Palatset', 4),
#  ('terrassen', 4),
#  ('altare', 4),
#  ('A', 4),
#  ('Sammansatt bild', 4),
#  ('Plakes', 4),
#  ('Livet', 4),
#  ('Jakovos Erik', 4),
#  ('Stockholm Cypernsamlingen', 4),
#  ('Badstranden', 4),
#  ('Kameler', 4),
#  ('Eleni', 4),
#  ('Gunnis', 4),
#  ('Stefan Gjerstad', 4),
#  ('Stockholm Souidos', 4),
#  ('Idalion Avskedsfesten', 4),
#  ('besök', 4),
#  ('Avskedsfesten Panajiotis', 4),
#  ('Stockholm ”Före', 4),
#  ('Stefan', 4),
#  ('Akropolen', 4),
#  ('Livet terrassen', 4),
#  ('svenska', 4),
#  ('Palatset Vouni', 4),
#  ('sydväst', 4),
#  ('Avskedsfesten', 4),
#  ('fyndlagret Amathus', 4),
#  ('Nicosia Erik', 4),
#  ('Sektion', 4),
#  ('Kultrummet', 4),
#  ('Lapitos', 4),
#  ('Sammansatt', 4),
#  ('orkestran Soli', 4),
#  ('Festgeten', 4),
#  ('arbetsbild Marion', 3),
#  ('stallet Stockholm', 3),
#  ('XLIII', 3),
#  ('Galini Galini', 3),
#  ('kamel Nicosia', 3),
#  ('rider kamel', 3),
#  ('Westholm Stockholm', 3),
#  ('Kition Kition', 3),
#  ('H 14-15', 3),
#  ('dromos Lapithos', 3),
#  ('utställningen Historiska', 3),
#  ('L Ajia', 3),
#  ('Soli Soli', 3),
#  ('Stockholm Alfred', 3),
#  ('Kountoura Trachonia', 3),
#  ('svenska Nicosia', 3),
#  ('Vouni Alfred', 3),
#  ('Lapithos Lapitos', 3),
#  ('Lindros Vouni', 3),
#  ('Historiska Museet', 3),
#  ('Gjerstad rider', 3),
#  ('Kition Kultrummet', 3),
#  ('120 Sammansatt', 3),
#  ('Volvo Nicosia', 3),
#  ('Jakovos Ajios', 3),
#  ('Sjöqvist Einar', 3),
#  ('Soli orkestran', 3),
#  ('Cypern utställningen', 3),
#  ('fynd Amathus', 3),
#  ('Westholm svenska', 3),
#  ('Rum XLIII', 3),
#  ('Lazaros Vouni', 3),
#  ('Nicosia Vivi', 3),
#  ('Fylleri Kythrea', 3),
#  ('Lindros Alfred', 3),
#  ('Westholm Erik', 3),
#  ('utgrävningen Soli', 3),
#  ('nordväst Vouni', 3),
#  ('palatset Vouni', 3),
#  ('A offergropen', 3),
#  ('XLIII A', 3),
#  ('Westholm Soli', 3),
#  ('K Idalion', 3),
#  ('Skala 120', 3),
#  ('rider', 3),
#  ('Lidros filmar', 2),
#  ('Avlöning Vouni', 2),
#  ('Joan du', 2),
#  ('Pezoullia provschakt', 2),
#  ('grav Paleoskoutella', 2),
#  ('geten Filoxenos', 2),
#  ('Museet Cypern', 2)]

# %% [markdown]
# # 2. Create new filenames for the images

# %% [raw]
# $ cypern.columns
#
# Index(['Fotonummer', 'Postnr.', 'Nyckelord', 'Beskrivning', 'Land, foto',
#        'Region, foto', 'Ort, foto', 'Geograf namn, alternativ', 'Fotodatum',
#        'Personnamn / fotograf', 'Personnamn / avbildad', 'Sökord',
#        'Händelse / var närvarande vid', 'Länk'],
#       dtype='object')

# %%
def save_filename_to_filename_file(filname_file, filename):
    """Create a file mapping original filenames and their folders with new
    Commons filenames according to <Task X on Phabricator>"""
    folder = row["Folder"]
    file = row["Filename"]
    # Filename: <Filename_1_clean>_-_DecArch_-_<Folder_#>-<Filename_0_clean>.<ext>
    
    #print("filename: {}".format(filename))
    filenames_file.write("{}|{}|{}\n".format(row["Folder"],row["Filename"],filename))

# %%
def get_foldernames_and_filenames(inpath):
# Out:
#   File "<ipython-input-11-04e94e1c82c0>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def create_filenames(fold, foldobj):

# %%
filenames_file = open("./filenames_mapping.csv","w")
filenames_file.write("Folder|Original|Commons\n")

for row_index, row in cypern.iterrows():
    filename = create_filename(row["Folder"], row["Filename"])
    save_filename_to_filename_file(filenames_file, filename)

# %% [markdown]
# Infobox mapping is available on [Phabricator](https://phabricator.wikimedia.org/T144485)
#
# # Cypern-samlingen

# %%
filenames_dict = {}
for index, row in cypern.iterrows():
